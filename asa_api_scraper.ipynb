# %%
import requests
import pandas as pd

# %%
def fetch_data(endpoint_url):

    response = requests.get(endpoint_url)
    
    # check if request was successful
    if response.status_code == 200:
    
        data = response.json()
        
        df = pd.DataFrame(data)
        
        return df
    else:
        print(f"Failed to fetch data from the endpoint: {endpoint_url}")
        return None

# %%
base_url_template = "https://app.americansocceranalysis.com/api/v1/{league}/{endpoint}"

# %%
endpoints = {
    "MLS": [
        "players",
        "players/xgoals",
        "players/xpass",
        "players/goals-added",
        "players/salaries",
        "goalkeepers/xgoals",
        "goalkeepers/goals-added",
        "teams",
        "teams/xgoals",
        "teams/xpass",
        "teams/goals-added",
        "teams/salaries",
        "games",
        "games/xgoals",
        "managers",
        "referees",
        "stadia"
    ],
    "NWSL": [
        "players",
        "players/xgoals",
        "players/xpass",
        "players/goals-added",
        "goalkeepers/xgoals",
        "goalkeepers/goals-added",
        "teams",
        "teams/xgoals",
        "teams/xpass",
        "teams/goals-added",
        "teams/salaries",
        "games",
        "games/xgoals",
        "managers",
        "referees",
        "stadia"
    ],
    "USLC": [
        "players",
        "players/xgoals",
        "players/xpass",
        "players/goals-added",
        "goalkeepers/xgoals",
        "goalkeepers/goals-added",
        "teams",
        "teams/xgoals",
        "teams/xpass",
        "teams/goals-added",
        "teams/salaries",
        "games",
        "games/xgoals",
        "managers",
        "referees",
        "stadia"
    ],
    "USL1": [
        "players",
        "players/xgoals",
        "players/xpass",
        "players/goals-added",
        "goalkeepers/xgoals",
        "goalkeepers/goals-added",
        "teams",
        "teams/xgoals",
        "teams/xpass",
        "teams/goals-added",
        "teams/salaries",
        "games",
        "games/xgoals",
        "managers",
        "referees",
        "stadia"
    ],
    "MLSNP": [
        "players",
        "players/xgoals",
        "players/xpass",
        "players/goals-added",
        "goalkeepers/xgoals",
        "goalkeepers/goals-added",
        "teams",
        "teams/xgoals",
        "teams/xpass",
        "teams/goals-added",
        "teams/salaries",
        "games",
        "games/xgoals",
        "managers",
        "referees",
        "stadia"
    ],
    "NASL": [
        "players",
        "players/xgoals",
        "players/xpass",
        "players/goals-added",
        "goalkeepers/xgoals",
        "goalkeepers/goals-added",
        "teams",
        "teams/xgoals",
        "teams/xpass",
        "teams/goals-added",
        "teams/salaries",
        "games",
        "games/xgoals",
        "managers",
        "referees",
        "stadia"
    ]
}

# dictionary of dataframes for each league
league_dfs = {}

# %%
# fetch data and store in dataframes
for league, endpoint_list in endpoints.items():
    league_dfs[league] = {}
    for endpoint in endpoint_list:
        endpoint_url = base_url_template.format(league=league.lower(), endpoint=endpoint)
        df = fetch_data(endpoint_url)
        if df is not None:
            league_dfs[league][endpoint] = df
# Out:
# Failed to fetch data from the endpoint: https://app.americansocceranalysis.com/api/v1/mls/teams/salaries
# Failed to fetch data from the endpoint: https://app.americansocceranalysis.com/api/v1/nwsl/teams/salaries
# Failed to fetch data from the endpoint: https://app.americansocceranalysis.com/api/v1/uslc/teams/salaries
# Failed to fetch data from the endpoint: https://app.americansocceranalysis.com/api/v1/usl1/teams/salaries
# Failed to fetch data from the endpoint: https://app.americansocceranalysis.com/api/v1/mlsnp/teams/salaries
# Failed to fetch data from the endpoint: https://app.americansocceranalysis.com/api/v1/nasl/teams/salaries

# %%
league_dfs["MLSNP"]["teams"]
# Out:
#        team_id                  team_name   team_short_name team_abbreviation
# 0   0Oq6Yad56D            Columbus Crew 2          Columbus               CLB
# 1   0x5gb3bM7O         Chicago Fire FC II           Chicago               CHI
# 2   2lqRX1AMr0      Minnesota United FC 2         Minnesota               MIN
# 3   2vQ14GKqrA    Sporting Kansas City II       Kansas City               SKC
# 4   2vQ1XzlqrA           Los Angeles FC 2  Los Angeles FC 2              LAFC
# 5   4JMAkpDqKg              Toronto FC II           Toronto               TOR
# 6   4wM4E4d5jB               LA Galaxy II      LA Galaxy II               LAG
# 7   7VqG1oWMvW          Colorado Rapids 2          Colorado               COL
# 8   9Yqdwg85vJ      New York Red Bulls II          New York              NYRB
# 9   a35reDLML6            Crown Legacy FC         Charlotte               CLT
# 10  BLMv6m3Mxe              Real Monarchs     Real Monarchs               SLC
# 11  eV5Dw4EMKn               Austin FC II            Austin               ATX
# 12  eVq3Z0D5WO        St. Louis City SC 2         St. Louis               STL
# 13  gOMnJnOMwN        Houston Dynamo FC 2           Houston               HOU
# 14  gpMO1Pyqzy  New England Revolution II       New England               NER
# 15  gpMOXy25zy            FC Cincinnati 2        Cincinnati               CIN
# 16  jYQJXkP5GR        New York City FC II     New York City               NYC
# 17  KPqj6bBq6v      Rochester New York FC         Rochester               ROC
# 18  KPqjwN4Q6v      Philadelphia Union II      Philadelphia               PHI
# 19  kRQaW3L5KZ             Orlando City B      Orlando City               ORL
# 20  KXMe8Z2Q64            Tacoma Defiance            Tacoma               TAC
# 21  ljqE94Vqx0             North Texas SC       North Texas               NTX
# 22  N6MmWV0qEG   Vancouver Whitecaps FC 2         Vancouver               VAN
# 23  NWMWJezQlz              Carolina Core          Carolina              CCFC
# 24  Oa5wDy8q14    San Jose Earthquakes II          San Jose               SJE
# 25  OlMlKDEQLz         Huntsville City FC        Huntsville               HNT
# 26  raMyeZAMd2             Chattanooga FC       Chattanooga               CFC
# 27  vzqowoZqap          Inter Miami CF II             Miami               MIA
# 28  wvq9jx1QWn           Atlanta United 2           Atlanta               ATL
# 29  zeQZe4DqKw         Portland Timbers 2          Portland               POR

# %%
# display dataframes of each league
for league, dataframes in league_dfs.items():
    print(f"\n{league} DataFrames:")
    for endpoint, df in dataframes.items():
        print(f"\n{endpoint} DataFrame:")
        print(df.head())
# Out:
# MLS DataFrames:
#
# players DataFrame:
#     player_id       player_name  birth_date  height_ft  height_in  weight_lb  \
# 0  0Oq6006M6D       Ugo Ihemelu  1983-04-03        6.0        0.0      179.0
# 1  0Oq60APM6D   Jason Hernandez  1983-08-26        5.0       11.0      172.0
# 2  0Oq60VgM6D  Jeff Larentowicz  1983-08-05        6.0        1.0      176.0
# 3  0Oq62Y3zq6      Isaac Walker  2000-07-03        NaN        NaN        NaN
# 4  0Oq630dXQ6      Kevin Cabral  1999-07-10        NaN        NaN        NaN
#
#   nationality                                       season_name  \
# 0         USA                                                {}
# 1         USA              [2013, 2014, 2015, 2016, 2017, 2018]
# 2         USA  [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# 3         USA                                                {}
# 4      France                          [2021, 2022, 2023, 2024]
#
#   primary_broad_position primary_general_position secondary_general_position  \
# 0                    NaN                      NaN                        NaN
# 1                     DF                       CB                        NaN
# 2                     MF                       DM                         CM
# 3                    NaN                      NaN                        NaN
# 4                     MF                        W                         ST
#
#   secondary_broad_position
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                       FW
#
# players/xgoals DataFrame:
#     player_id                               team_id general_position  \
# 0  0Oq60APM6D  [kRQabn8MKZ, 0KPqjA456v, Vj58weDM8n]               CB
# 1  0Oq60VgM6D  [KAqBN0Vqbg, kaDQ0wRqEv, X0Oq66zq6D]               DM
# 2  0Oq630dXQ6              [kaDQ0wRqEv, pzeQZ6xQKw]                W
# 3  0Oq632k7Q6              [pzeQZ6xQKw, jYQJ19EqGR]               CM
# 4  0Oq633dAQ6                            EKXMeX3Q64                W
#
#    minutes_played  shots  shots_on_target  goals   xgoals  xplace  \
# 0            9774      4                0      0   0.5459 -0.5459
# 1           20303    196               57     19  22.4174 -3.6930
# 2            5542    106               50      9  17.7805 -1.2947
# 3            3427     27                6      0   1.0045  0.3792
# 4            1112     16                9      3   0.9513  0.1589
#
#    goals_minus_xgoals  key_passes  primary_assists  xassists  \
# 0             -0.5459          11                0    0.8302
# 1             -3.4174          72                9    6.5441
# 2             -8.7805          50                5    6.4740
# 3             -1.0045          37                1    2.8147
# 4              2.0487           9                1    1.2744
#
#    primary_assists_minus_xassists  xgoals_plus_xassists  points_added  \
# 0                         -0.8302                1.3761        0.0000
# 1                          2.4559               28.9615        9.5505
# 2                         -1.4740               24.2546        6.8375
# 3                         -1.8147                3.8191        0.0000
# 4                         -0.2744                2.2257        2.0103
#
#    xpoints_added
# 0         0.3505
# 1        14.3498
# 2        11.8479
# 3         0.7605
# 4         0.4626
#
# players/xpass DataFrame:
#     player_id                               team_id general_position  \
# 0  0Oq60APM6D  [kRQabn8MKZ, 0KPqjA456v, Vj58weDM8n]               CB
# 1  0Oq60VgM6D  [KAqBN0Vqbg, kaDQ0wRqEv, X0Oq66zq6D]               DM
# 2  0Oq630dXQ6              [kaDQ0wRqEv, pzeQZ6xQKw]                W
# 3  0Oq632k7Q6              [pzeQZ6xQKw, jYQJ19EqGR]               CM
# 4  0Oq633dAQ6                            EKXMeX3Q64                W
#
#    minutes_played  attempted_passes  pass_completion_percentage  \
# 0            9774              3683                      0.8167
# 1           20303              9151                      0.8258
# 2            5542              1414                      0.7645
# 3            3427              1933                      0.8308
# 4            1112               258                      0.6744
#
#    xpass_completion_percentage  passes_completed_over_expected  \
# 0                       0.8041                         46.4631
# 1                       0.8273                        -14.0415
# 2                       0.8000                        -50.1940
# 3                       0.8287                          4.0343
# 4                       0.7329                        -15.0928
#
#    passes_completed_over_expected_p100  avg_distance_yds  \
# 0                               1.2616           22.9373
# 1                              -0.1534           21.6210
# 2                              -3.5498           15.8543
# 3                               0.2087           18.2407
# 4                              -5.8499           17.5191
#
#    avg_vertical_distance_yds  share_team_touches  count_games
# 0                     9.1718              0.0690          116
# 1                     6.7459              0.0774          241
# 2                    -2.0353              0.0362           94
# 3                     4.4180              0.0528           73
# 4                    -0.4031              0.0256           32
#
# players/goals-added DataFrame:
#     player_id                               team_id general_position  \
# 0  0Oq60APM6D  [kRQabn8MKZ, 0KPqjA456v, Vj58weDM8n]               CB
# 1  0Oq60VgM6D  [KAqBN0Vqbg, kaDQ0wRqEv, X0Oq66zq6D]               DM
# 2  0Oq630dXQ6              [kaDQ0wRqEv, pzeQZ6xQKw]                W
# 3  0Oq632k7Q6              [pzeQZ6xQKw, jYQJ19EqGR]               CM
# 4  0Oq633dAQ6                            EKXMeX3Q64                W
#
#    minutes_played                                               data
# 0            9774  [{'action_type': 'Dribbling', 'goals_added_raw...
# 1           20303  [{'action_type': 'Dribbling', 'goals_added_raw...
# 2            5542  [{'action_type': 'Dribbling', 'goals_added_raw...
# 3            3427  [{'action_type': 'Dribbling', 'goals_added_raw...
# 4            1112  [{'action_type': 'Dribbling', 'goals_added_raw...
#
# players/salaries DataFrame:
#     player_id     team_id  season_name position  base_salary  \
# 0  0Oq6006M6D  mKAqBBmqbg         2013        D     200000.0
# 1  0Oq6006M6D  mKAqBBmqbg         2013        D     200000.0
# 2  0Oq6006M6D  mKAqBBmqbg         2013        D     200000.0
# 3  0Oq60APM6D  0KPqjA456v         2013        D     205000.0
# 4  0Oq60APM6D  0KPqjA456v         2013        D     205000.0
#
#    guaranteed_compensation mlspa_release
# 0                200000.00    2013-05-01
# 1                200000.00    2013-08-01
# 2                200000.00    2013-09-15
# 3                208333.33    2013-05-01
# 4                208333.33    2013-08-01
#
# goalkeepers/xgoals DataFrame:
#     player_id                   team_id  minutes_played  shots_faced  \
# 0  0Oq6woOxQ6                mKAqBBmqbg            7133          303
# 1  0x5g1BmQ7O                9z5k7Yg5A3             879           33
# 2  0x5g2Z8ZM7                NPqxKXZ59d            6222          281
# 3  0x5gP64wq7  [a2lqR4JMr0, WBLMvYAQxe]            8394          420
# 4  0x5gP9Jjq7  [19vQ2095K6, jYQJ8EW5GR]            2105          102
#
#    goals_conceded  saves  share_headed_shots  xgoals_gk_faced  \
# 0              76    216              0.1353          81.1572
# 1              13     17              0.2424          11.3395
# 2              89    187              0.0996          83.4528
# 3             131    287              0.1500         138.8680
# 4              41     59              0.1373          37.0250
#
#    goals_minus_xgoals_gk  goals_divided_by_xgoals_gk
# 0                -5.1572                      0.9365
# 1                 1.6605                      1.1464
# 2                 5.5472                      1.0665
# 3                -7.8680                      0.9433
# 4                 3.9750                      1.1074
#
# goalkeepers/goals-added DataFrame:
#     player_id                   team_id  minutes_played  \
# 0  0Oq6woOxQ6                mKAqBBmqbg            7133
# 1  0x5g1BmQ7O                9z5k7Yg5A3             879
# 2  0x5g2Z8ZM7                NPqxKXZ59d            6222
# 3  0x5gP64wq7  [a2lqR4JMr0, WBLMvYAQxe]            8394
# 4  0x5gP9Jjq7  [19vQ2095K6, jYQJ8EW5GR]            2105
#
#                                                 data
# 0  [{'action_type': 'Claiming', 'goals_added_raw'...
# 1  [{'action_type': 'Claiming', 'goals_added_raw'...
# 2  [{'action_type': 'Claiming', 'goals_added_raw'...
# 3  [{'action_type': 'Claiming', 'goals_added_raw'...
# 4  [{'action_type': 'Claiming', 'goals_added_raw'...
#
# teams DataFrame:
#       team_id               team_name team_short_name team_abbreviation
# 0  0KPqjA456v    San Jose Earthquakes        San Jose               SJE
# 1  19vQ2095K6  New England Revolution     New England               NER
# 2  4wM42l4qjB              Chivas USA          Chivas               CHV
# 3  9z5k7Yg5A3      Philadelphia Union    Philadelphia               PHI
# 4  a2lqR4JMr0          Real Salt Lake       Salt Lake               RSL
#
# teams/xgoals DataFrame:
#       team_id  count_games  shots_for  shots_against  goals_for  \
# 0  0KPqjA456v          374       4898           5092        459
# 1  19vQ2095K6          385       5087           5124        554
# 2  4wM42l4qjB           68        655            961         56
# 3  9z5k7Yg5A3          385       5022           4708        583
# 4  a2lqR4JMr0          389       5103           4989        541
#
#    goals_against  goal_difference  xgoals_for  xgoals_against  \
# 0            587             -128    486.2932        553.1295
# 1            544               10    528.4963        558.9570
# 2            127              -71     59.4626        102.2025
# 3            492               91    561.7772        497.3038
# 4            543               -2    501.1330        561.5094
#
#    xgoal_difference  goal_difference_minus_xgoal_difference  points  xpoints
# 0          -66.8363                                -61.1637     435  470.073
# 1          -30.4607                                 40.4607     555  498.896
# 2          -42.7399                                -28.2601      59   63.390
# 3           64.4734                                 26.5266     572  539.057
# 4          -60.3764                                 58.3764     548  483.868
#
# teams/xpass DataFrame:
#       team_id  count_games  attempted_passes_for  \
# 0  0KPqjA456v          374                177074
# 1  19vQ2095K6          385                176543
# 2  4wM42l4qjB           68                 26757
# 3  9z5k7Yg5A3          385                171435
# 4  a2lqR4JMr0          389                186145
#
#    pass_completion_percentage_for  xpass_completion_percentage_for  \
# 0                          0.7840                           0.7835
# 1                          0.7661                           0.7662
# 2                          0.7266                           0.7546
# 3                          0.7556                           0.7574
# 4                          0.7849                           0.7830
#
#    passes_completed_over_expected_for  \
# 0                             98.0327
# 1                            -27.8502
# 2                           -749.5483
# 3                           -307.5465
# 4                            358.4097
#
#    passes_completed_over_expected_p100_for  avg_vertical_distance_for  \
# 0                                   0.0554                     7.2420
# 1                                  -0.0158                     8.1131
# 2                                  -2.8013                     9.5975
# 3                                  -0.1794                     8.1831
# 4                                   0.1925                     7.3442
#
#    attempted_passes_against  pass_completion_percentage_against  \
# 0                    171959                              0.7811
# 1                    184896                              0.7767
# 2                     34878                              0.7900
# 3                    187242                              0.7822
# 4                    172693                              0.7675
#
#    xpass_completion_percentage_against  \
# 0                               0.7757
# 1                               0.7746
# 2                               0.7878
# 3                               0.7822
# 4                               0.7704
#
#    passes_completed_over_expected_against  \
# 0                                932.4477
# 1                                386.3203
# 2                                 79.8180
# 3                                -10.8867
# 4                               -505.4438
#
#    passes_completed_over_expected_p100_against  avg_vertical_distance_against  \
# 0                                       0.5423                         7.5325
# 1                                       0.2089                         7.6271
# 2                                       0.2288                         7.3749
# 3                                      -0.0058                         7.3113
# 4                                      -0.2927                         7.8520
#
#    passes_completed_over_expected_difference  avg_vertical_distance_difference
# 0                                  -834.4151                           -0.2905
# 1                                  -414.1705                            0.4859
# 2                                  -829.3663                            2.2225
# 3                                  -296.6598                            0.8719
# 4                                   863.8535                           -0.5077
#
# teams/goals-added DataFrame:
#       team_id  minutes                                               data
# 0  0KPqjA456v    37054  [{'action_type': 'Passing', 'num_actions_for':...
# 1  19vQ2095K6    38190  [{'action_type': 'Receiving', 'num_actions_for...
# 2  4wM42l4qjB     6690  [{'action_type': 'Claiming', 'num_actions_for'...
# 3  9z5k7Yg5A3    38283  [{'action_type': 'Passing', 'num_actions_for':...
# 4  a2lqR4JMr0    38752  [{'action_type': 'Receiving', 'num_actions_for...
#
# games DataFrame:
#       game_id            date_time_utc  home_score  away_score home_team_id  \
# 0  4JMAnzGl5K  2024-03-31 19:45:00 UTC           3           0   KAqBN0Vqbg
# 1  kRQazAEmMK  2024-03-31 02:30:00 UTC           3           2   lgpMOvnQzy
# 2  xW5pJNlGQg  2024-03-31 02:30:00 UTC           1           0   kaDQ0wRqEv
# 3  2lqReAdA5r  2024-03-31 01:30:00 UTC           3           1   a2lqR4JMr0
# 4  KXMezybX56  2024-03-31 00:30:00 UTC           2           1   gpMOLwl5zy
#
#   away_team_id  referee_id  stadium_id home_manager_id away_manager_id  \
# 0   X0Oq66zq6D  2lqRG1WQr0  NWMWoaeMlz      7vQ7m6Y5D1      gOMnBPJMwN
# 1   WBLMvYAQxe  vzqoWjkqap  ljqEDnO5x0      Pk5LWONMOW      gpMOYJ7qzy
# 2   jYQJ19EqGR  e7MzPKXqr0  wvq9p1Y5Wn      Xj5Yx60Mbd      odMXxreMYL
# 3   wvq9B9wQWn  Pk5LRpDQOW  e7MzlRjqr0      4wM4vOAqjB      zeQZVw1QKw
# 4   mKAqBBmqbg  9vQ2mPaqK6  jYQJZDDQGR      0Oq6mNP56D      KAqBwv7Qbg
#
#    expanded_minutes season_name  matchday  attendance  knockout_game  \
# 0                99        2024         6       42525          False
# 1                98        2024         6       24693          False
# 2                98        2024         6       22736          False
# 3               107        2024         6       19357          False
# 4               102        2024         6       20738          False
#
#           last_updated_utc extra_time penalties  home_penalties  \
# 0  2024-04-01 11:29:14 UTC        NaN       NaN             NaN
# 1  2024-04-01 14:36:01 UTC        NaN       NaN             NaN
# 2  2024-04-01 14:50:26 UTC        NaN       NaN             NaN
# 3  2024-04-01 11:28:45 UTC        NaN       NaN             NaN
# 4  2024-04-01 15:41:01 UTC        NaN       NaN             NaN
#
#    away_penalties
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# games/xgoals DataFrame:
#       game_id            date_time_utc home_team_id  home_goals  \
# 0  4JMAnzGl5K  2024-03-31 19:45:00 UTC   KAqBN0Vqbg           3
# 1  kRQazAEmMK  2024-03-31 02:30:00 UTC   lgpMOvnQzy           3
# 2  xW5pJNlGQg  2024-03-31 02:30:00 UTC   kaDQ0wRqEv           1
# 3  2lqReAdA5r  2024-03-31 01:30:00 UTC   a2lqR4JMr0           3
# 4  KXMezybX56  2024-03-31 00:30:00 UTC   gpMOLwl5zy           2
#
#    home_team_xgoals  home_player_xgoals away_team_id  away_goals  \
# 0            3.1501              3.2481   X0Oq66zq6D           0
# 1            1.8065              2.1136   WBLMvYAQxe           2
# 2            0.6819              0.6836   jYQJ19EqGR           0
# 3            1.9656              1.9748   wvq9B9wQWn           1
# 4            1.9388              2.1044   mKAqBBmqbg           1
#
#    away_team_xgoals  away_player_xgoals  goal_difference  \
# 0            0.7427              0.7427                3
# 1            0.8087              0.8087                1
# 2            1.5369              1.5369                1
# 3            0.6320              0.6320                2
# 4            0.9550              0.9550                1
#
#    team_xgoal_difference  player_xgoal_difference  final_score_difference  \
# 0                 2.4074                   2.5054                       3
# 1                 0.9978                   1.3049                       1
# 2                -0.8550                  -0.8532                       1
# 3                 1.3335                   1.3427                       2
# 4                 0.9839                   1.1494                       1
#
#    home_xpoints  away_xpoints
# 0         2.709         0.207
# 1         2.149         0.619
# 2         0.721         2.029
# 3         2.424         0.405
# 4         2.081         0.719
#
# managers DataFrame:
#    manager_id     manager_name nationality
# 0  0Oq6e7A56D    Rob Valentino         USA
# 1  0Oq6mNP56D       Josh Wolff         USA
# 2  0Oq6mxd56D  Marc Dos Santos      Canada
# 3  0Oq6VPgq6D     Robin Fraser         USA
# 4  0Oq6vPrq6D       Jim Curtin         USA
#
# referees DataFrame:
#    referee_id        referee_name  birth_date          nationality
# 0  0Oq6037M6D          Alan Kelly  1975-04-09  Republic of Ireland
# 1  0Oq60rxM6D    Matthew Foerster         NaN                  USA
# 2  0Oq6mnX56D     Michael Radchuk         NaN                  USA
# 3  0Oq6vG2q6D  Marcos de Oliveira         NaN                  USA
# 4  0x5gg0j57O         Amin Hadzic         NaN                  USA
#
# stadia DataFrame:
#    stadium_id     stadium_name  capacity  year_built   roof   turf  \
# 0  0x5g6ojM7O      PNC Stadium   22039.0      2012.0  False  False
# 1  0x5gJZjM7O  DRV PNK Stadium   18000.0      2020.0  False  False
# 2  2lqRRVnqr0        BMO Field   30991.0      2007.0  False  False
# 3  2vQ1eawQrA  Lower.com Field   20371.0      2021.0  False  False
# 4  4wM4ez45jB  Centene Stadium       NaN         NaN    NaN    NaN
#
#                    street             city province country postal_code  \
# 0       2200 Texas Avenue          Houston    Texas     USA       77590
# 1     1350 NW 55th Street  Fort Lauderdale  Florida     USA       33309
# 2  170 Princes' Boulevard          Toronto  Ontario  Canada     M6K 3C3
# 3    96 Columbus Crew Way         Columbus     Ohio     USA       43215
# 4                     NaN              NaN      NaN     NaN         NaN
#
#    latitude  longitude  field_x  field_y
# 0   29.7522   -95.3524    115.0     73.0
# 1   26.1931   -80.1611      NaN      NaN
# 2   43.6328   -79.4186    115.0     74.0
# 3   39.9685   -83.0171    115.0     75.0
# 4       NaN        NaN      NaN      NaN
#
# NWSL DataFrames:
#
# players DataFrame:
#     player_id      player_name  birth_date nationality primary_broad_position  \
# 0  0Oq6243Pq6      Lena Silano  2000-02-28         USA                     FW
# 1  0Oq632XPQ6  Jenna Hellstrom  1995-04-02      Canada                     DF
# 2  0Oq63d8XQ6    Maddie Huster  1996-07-05         USA                    NaN
# 3  0Oq63dogQ6   Paige Monaghan  1996-11-13         USA                     MF
# 4  0Oq63dpzQ6      Erin Yenney  1992-10-20         USA                     FW
#
#   primary_general_position secondary_broad_position  \
# 0                       ST                       MF
# 1                       FB                      NaN
# 2                      NaN                      NaN
# 3                        W                       FW
# 4                        W                       MF
#
#   secondary_general_position                           season_name  height_ft  \
# 0                          W                                  2023        NaN
# 1                        NaN                                  2020        5.0
# 2                        NaN                                    {}        5.0
# 3                          W  [2019, 2020, 2021, 2022, 2023, 2024]        5.0
# 4                          W                                  2018        5.0
#
#    height_in  weight_lb
# 0        NaN        NaN
# 1        6.0        NaN
# 2        4.0        NaN
# 3        7.0        NaN
# 4        7.0        NaN
#
# players/xgoals DataFrame:
#     player_id                               team_id general_position  \
# 0  0Oq6243Pq6                            aDQ0lzvQEv                W
# 1  0Oq632XPQ6                            aDQ0lzvQEv               FB
# 2  0Oq63dogQ6  [eV5D2w9QKn, eV5DR6YQKn, raMyrr25d2]                W
# 3  0Oq63dpzQ6                            KPqjw8PQ6v                W
# 4  0Oq63NGdQ6              [4wM4rZdqjB, eV5D2w9QKn]               FB
#
#    minutes_played  shots  shots_on_target  goals   xgoals  xplace  \
# 0             910     16                4      1   0.9462 -0.3308
# 1             253      4                0      0   0.2499 -0.2499
# 2            7859    156               48     14  13.9344  0.1841
# 3              42      3                1      0   0.1748  0.0774
# 4            6560     44               10      2   4.5741 -2.3691
#
#    goals_minus_xgoals  key_passes  primary_assists  xassists  \
# 0              0.0538           9                3    0.8561
# 1             -0.2499           2                0    0.0510
# 2              0.0656          84                6    9.8138
# 3             -0.1748           0                0    0.0000
# 4             -2.5741          32                4    4.2070
#
#    primary_assists_minus_xassists  xgoals_plus_xassists  points_added  \
# 0                          2.1439                1.8023        0.7813
# 1                         -0.0510                0.3009        0.0000
# 2                         -3.8138               23.7482        4.9829
# 3                          0.0000                0.1748        0.0000
# 4                         -0.2070                8.7811        0.3570
#
#    xpoints_added
# 0         0.8322
# 1         0.2827
# 2         7.7721
# 3         0.1327
# 4         2.6494
#
# players/xpass DataFrame:
#     player_id                               team_id general_position  \
# 0  0Oq6243Pq6                            aDQ0lzvQEv                W
# 1  0Oq632XPQ6                            aDQ0lzvQEv               FB
# 2  0Oq63dogQ6  [eV5D2w9QKn, eV5DR6YQKn, raMyrr25d2]                W
# 3  0Oq63dpzQ6                            KPqjw8PQ6v                W
# 4  0Oq63NGdQ6              [4wM4rZdqjB, eV5D2w9QKn]               FB
#
#    minutes_played  attempted_passes  pass_completion_percentage  \
# 0             910               165                      0.5515
# 1             253               131                      0.7786
# 2            7859              2495                      0.6349
# 3              42                21                      0.5714
# 4            6560              3183                      0.7370
#
#    xpass_completion_percentage  passes_completed_over_expected  \
# 0                       0.6056                         -8.9244
# 1                       0.7667                          1.5648
# 2                       0.6804                       -113.4810
# 3                       0.7522                         -3.7959
# 4                       0.7398                         -8.8130
#
#    passes_completed_over_expected_p100  avg_distance_yds  \
# 0                              -5.4087           19.8924
# 1                               1.1945           18.9808
# 2                              -4.5483           17.6335
# 3                             -18.0759           18.7330
# 4                              -0.2769           18.5229
#
#    avg_vertical_distance_yds  share_team_touches  count_games
# 0                     2.6107              0.0323           18
# 1                    -1.8087              0.0399            6
# 2                     2.1994              0.0549          112
# 3                     0.8328              0.0143            3
# 4                     6.0135              0.0896           80
#
# players/goals-added DataFrame:
#     player_id                               team_id general_position  \
# 0  0Oq6243Pq6                            aDQ0lzvQEv                W
# 1  0Oq632XPQ6                            aDQ0lzvQEv               FB
# 2  0Oq63dogQ6  [eV5D2w9QKn, eV5DR6YQKn, raMyrr25d2]                W
# 3  0Oq63dpzQ6                            KPqjw8PQ6v                W
# 4  0Oq63NGdQ6              [4wM4rZdqjB, eV5D2w9QKn]               FB
#
#    minutes_played                                               data
# 0             910  [{'action_type': 'Dribbling', 'goals_added_raw...
# 1             253  [{'action_type': 'Dribbling', 'goals_added_raw...
# 2            7859  [{'action_type': 'Dribbling', 'goals_added_raw...
# 3              42  [{'action_type': 'Dribbling', 'goals_added_raw...
# 4            6560  [{'action_type': 'Dribbling', 'goals_added_raw...
#
# goalkeepers/xgoals DataFrame:
#     player_id                   team_id  minutes_played  shots_faced  \
# 0  0Oq6waLAQ6                4wM4Ezg5jB             873           66
# 1  0x5gW0mw57                Pk5LeeNqOW            1050           40
# 2  2lqRkPPnQr                4wM4Ezg5jB             935           63
# 3  4JMAaol2MK                7vQ7BBzqD1             671           45
# 4  4JMAkml7qK  [raMyrr25d2, eV5DR6YQKn]               6            0
#
#    goals_conceded  saves  share_headed_shots  xgoals_gk_faced  \
# 0              25     39              0.1364          17.2111
# 1              15     25              0.0500          13.2347
# 2              20     42              0.1429          16.1002
# 3               6     37              0.1333          10.3771
# 4               0      0              0.0000           0.0000
#
#    goals_minus_xgoals_gk  goals_divided_by_xgoals_gk
# 0                 7.7889                      1.4526
# 1                 1.7653                      1.1334
# 2                 3.8998                      1.2422
# 3                -4.3771                      0.5782
# 4                 0.0000                      0.0000
#
# goalkeepers/goals-added DataFrame:
#     player_id     team_id  minutes_played  \
# 0  0Oq6waLAQ6  4wM4Ezg5jB             873
# 1  0x5gW0mw57  Pk5LeeNqOW            1050
# 2  2lqRkPPnQr  4wM4Ezg5jB             935
# 3  4JMAaol2MK  7vQ7BBzqD1             671
# 4  4wM4Jnmgqj  4JMAk47qKg             888
#
#                                                 data
# 0  [{'action_type': 'Claiming', 'goals_added_raw'...
# 1  [{'action_type': 'Claiming', 'goals_added_raw'...
# 2  [{'action_type': 'Claiming', 'goals_added_raw'...
# 3  [{'action_type': 'Claiming', 'goals_added_raw'...
# 4  [{'action_type': 'Claiming', 'goals_added_raw'...
#
# teams DataFrame:
#       team_id            team_name team_short_name team_abbreviation
# 0  315VnJ759x               Bay FC          Bay FC               BAY
# 1  4JMAk47qKg         Houston Dash         Houston               HOU
# 2  4wM4Ezg5jB      Boston Breakers          Boston               BOS
# 3  4wM4rZdqjB  Kansas City Current     Kansas City                KC
# 4  7vQ7BBzqD1     Seattle Reign FC         Seattle               SEA
#
# teams/xgoals DataFrame:
#       team_id  count_games  shots_for  shots_against  goals_for  \
# 0  315VnJ759x            3         31             49          4
# 1  4JMAk47qKg          191       2459           2486        225
# 2  4wM4Ezg5jB           44        459            632         36
# 3  4wM4rZdqjB           92       1113           1229        116
# 4  7vQ7BBzqD1          196       2622           2551        251
#
#    goals_against  goal_difference  xgoals_for  xgoals_against  \
# 0              5               -1      2.2822          6.4329
# 1            256              -31    228.7009        247.1352
# 2             80              -44     38.9905         66.1743
# 3            123               -7    119.4146        119.6369
# 4            198               53    252.2692        232.7398
#
#    xgoal_difference  goal_difference_minus_xgoal_difference  points  xpoints
# 0           -4.1507                                  3.1507       3    1.316
# 1          -18.4342                                -12.5658     240  239.612
# 2          -27.1838                                -16.8162      30   43.448
# 3           -0.2223                                 -6.7777     120  122.554
# 4           19.5294                                 33.4706     309  270.366
#
# teams/xpass DataFrame:
#       team_id  count_games  attempted_passes_for  \
# 0  315VnJ759x            3                  1502
# 1  4JMAk47qKg          191                 82134
# 2  4wM4Ezg5jB           44                 17835
# 3  4wM4rZdqjB           92                 38355
# 4  7vQ7BBzqD1          196                 95125
#
#    pass_completion_percentage_for  xpass_completion_percentage_for  \
# 0                          0.7650                           0.7653
# 1                          0.7167                           0.7249
# 2                          0.6876                           0.6970
# 3                          0.7085                           0.7241
# 4                          0.7300                           0.7251
#
#    passes_completed_over_expected_for  \
# 0                             -0.4231
# 1                           -669.3334
# 2                           -167.2721
# 3                           -596.1795
# 4                            467.3143
#
#    passes_completed_over_expected_p100_for  avg_vertical_distance_for  \
# 0                                  -0.0282                     5.8279
# 1                                  -0.8149                     8.4775
# 2                                  -0.9379                     9.8061
# 3                                  -1.5544                     8.3638
# 4                                   0.4913                     7.7219
#
#    attempted_passes_against  pass_completion_percentage_against  \
# 0                      1476                              0.7425
# 1                     91730                              0.7463
# 2                     19631                              0.7166
# 3                     42356                              0.7346
# 4                     89380                              0.7163
#
#    xpass_completion_percentage_against  \
# 0                               0.7602
# 1                               0.7407
# 2                               0.7143
# 3                               0.7323
# 4                               0.7229
#
#    passes_completed_over_expected_against  \
# 0                                -26.0753
# 1                                512.4526
# 2                                 44.0219
# 3                                 96.7529
# 4                               -589.3695
#
#    passes_completed_over_expected_p100_against  avg_vertical_distance_against  \
# 0                                      -1.7666                         5.8914
# 1                                       0.5587                         7.5082
# 2                                       0.2242                         8.6808
# 3                                       0.2284                         7.5523
# 4                                      -0.6594                         8.2472
#
#    passes_completed_over_expected_difference  avg_vertical_distance_difference
# 0                                    25.6522                           -0.0635
# 1                                 -1181.7860                            0.9692
# 2                                  -211.2939                            1.1252
# 3                                  -692.9325                            0.8116
# 4                                  1056.6839                           -0.5253
#
# teams/goals-added DataFrame:
#       team_id  minutes                                               data
# 0  315VnJ759x      311  [{'action_type': 'Dribbling', 'num_actions_for...
# 1  4JMAk47qKg    18997  [{'action_type': 'Receiving', 'num_actions_for...
# 2  4wM4Ezg5jB     4309  [{'action_type': 'Dribbling', 'num_actions_for...
# 3  4wM4rZdqjB     9245  [{'action_type': 'Fouling', 'num_actions_for':...
# 4  7vQ7BBzqD1    18837  [{'action_type': 'Interrupting', 'num_actions_...
#
# games DataFrame:
#       game_id            date_time_utc  home_score  away_score home_team_id  \
# 0  7VqGPGBeQv  2024-03-31 17:00:00 UTC           2           1   aDQ0lzvQEv
# 1  0x5gzZBrM7  2024-03-31 02:00:00 UTC           2           3   315VnJ759x
# 2  NWMWzr77Ql  2024-03-30 23:30:00 UTC           2           2   Pk5LeeNqOW
# 3  KAqBow0JQb  2024-03-30 23:00:00 UTC           1           0   zeQZeazqKw
# 4  eVq3lEP6QW  2024-03-30 19:30:00 UTC           4           2   4wM4rZdqjB
#
#   away_team_id  referee_id  stadium_id home_manager_id away_manager_id  \
# 0   eV5D2w9QKn  EGMPOOyQaY  xW5pwORMg1      NPqxDAgq9d      7vQ7DeLMD1
# 1   4JMAk47qKg  2vQ1VL4MrA  Vj58W84M8n      NPqxLwgq9d      7VqG8GWQvW
# 2   eV5DR6YQKn  vzqokzpqap  p6qbX06M0G      gpMOpVy5zy      kRQa4GoqKZ
# 3   raMyrr25d2  9vQ28gY5K6  gpMOrLOQzy      p6qbJw3q0G      9vQ2r1LQK6
# 4   kRQa8JOqKZ  ljqEyb4qx0  xW5p3L0Mg1      vzqo3mNqap      kRQa4w8qKZ
#
#    expanded_minutes season_name  matchday  attendance  knockout_game  \
# 0               114        2024         3           0          False
# 1               108        2024         3       18000          False
# 2               107        2024         3       16688          False
# 3               100        2024         3        5281          False
# 4               112        2024         3           0          False
#
#           last_updated_utc extra_time  home_penalties  away_penalties  \
# 0  2024-03-31 19:26:58 UTC        NaN             NaN             NaN
# 1  2024-03-31 04:30:12 UTC        NaN             NaN             NaN
# 2  2024-03-31 02:09:47 UTC        NaN             NaN             NaN
# 3  2024-03-31 03:55:27 UTC        NaN             NaN             NaN
# 4  2024-03-30 21:52:27 UTC        NaN             NaN             NaN
#
#   penalties
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# games/xgoals DataFrame:
#       game_id            date_time_utc home_team_id  home_goals  \
# 0  7VqGPGBeQv  2024-03-31 17:00:00 UTC   aDQ0lzvQEv           2
# 1  0x5gzZBrM7  2024-03-31 02:00:00 UTC   315VnJ759x           2
# 2  NWMWzr77Ql  2024-03-30 23:30:00 UTC   Pk5LeeNqOW           2
# 3  KAqBow0JQb  2024-03-30 23:00:00 UTC   zeQZeazqKw           1
# 4  eVq3lEP6QW  2024-03-30 19:30:00 UTC   4wM4rZdqjB           4
#
#    home_team_xgoals  home_player_xgoals away_team_id  away_goals  \
# 0            2.8562              2.8625   eV5D2w9QKn           1
# 1            1.1318              1.1790   4JMAk47qKg           3
# 2            1.6516              1.6615   eV5DR6YQKn           2
# 3            0.9881              1.0108   raMyrr25d2           0
# 4            1.7041              1.7060   kRQa8JOqKZ           2
#
#    away_team_xgoals  away_player_xgoals  goal_difference  \
# 0            1.2975              1.3436                1
# 1            2.5980              2.5994               -1
# 2            1.1764              1.1764                0
# 3            1.0816              1.0837                1
# 4            1.3758              1.4012                2
#
#    team_xgoal_difference  player_xgoal_difference  final_score_difference  \
# 0                 1.5587                   1.5188                       1
# 1                -1.4661                  -1.4203                      -1
# 2                 0.4751                   0.4850                       0
# 3                -0.0935                  -0.0730                       1
# 4                 0.3282                   0.3048                       2
#
#    home_xpoints  away_xpoints
# 0         2.336         0.521
# 1         0.444         2.397
# 2         1.642         1.096
# 3         1.306         1.366
# 4         1.689         1.077
#
# managers DataFrame:
#    manager_id     manager_name nationality
# 0  0Oq6BpAq6D   James Clarkson         USA
# 1  0Oq6mKg56D    James Gabarra         USA
# 2  0x5gj0ZM7O      Matt Potter     England
# 3  2lqReDJ5r0  Lars Björkegren      Sweden
# 4  2lqREma5r0       Paul Riley     England
#
# referees DataFrame:
#    referee_id        referee_name nationality birth_date
# 0  0Oq6AZ756D  Ekaterina Koroleva         USA        NaN
# 1  0Oq6mnX56D     Michael Radchuk         USA        NaN
# 2  0Oq6mXx56D       Farhad Dadkho         USA        NaN
# 3  0x5gNljM7O        Mark Allatin         USA        NaN
# 4  2lqREOA5r0        Jared Simons         USA        NaN
#
# stadia DataFrame:
#    stadium_id                stadium_name  year_built  \
# 0  0Oq62v7q6D              Torero Stadium      1961.0
# 1  0x5g6ojM7O                 PNC Stadium      2012.0
# 2  0x5gJ7mM7O            Field of Legends         NaN
# 3  4wM4ZmdqjB     Rochester Rinos Stadium         NaN
# 4  7vQ7xbOMD1  Banc of California Stadium      2018.0
#
#                        street         city    province country postal_code  \
# 0        5998 Alcala Park Way    San Diego  California     USA       92111
# 1           2200 Texas Avenue      Houston       Texas     USA       77590
# 2                         NaN          NaN         NaN     NaN         NaN
# 3                         NaN          NaN         NaN     NaN         NaN
# 4  3939 South Figueroa Street  Los Angeles  California     USA       90037
#
#    capacity   roof   turf  latitude  longitude  field_x  field_y
# 0       NaN    NaN    NaN       NaN        NaN      NaN      NaN
# 1   22039.0  False  False   29.7522   -95.3524    115.0     73.0
# 2       NaN    NaN    NaN       NaN        NaN      NaN      NaN
# 3       NaN    NaN    NaN       NaN        NaN      NaN      NaN
# 4   22000.0  False  False   34.0130  -118.2850      NaN      NaN
#
# USLC DataFrames:
#
# players DataFrame:
#     player_id      player_name  birth_date  height_ft  height_in  weight_lb  \
# 0  0Oq60APM6D  Jason Hernandez  1983-08-26        5.0       11.0      172.0
# 1  0Oq6246gq6       Alex Dalou  2000-08-24        5.0        7.0        NaN
# 2  0Oq62e7Xq6              NaN         NaN        NaN        NaN        NaN
# 3  0Oq62Ym6q6       Joel Quist         NaN        NaN        NaN        NaN
# 4  0Oq62YXrq6        Jose Sosa  1999-09-10        NaN        NaN        NaN
#
#   nationality primary_broad_position primary_general_position   season_name  \
# 0         USA                     DF                       CB  [2017, 2018]
# 1         USA                     FW                       ST          2024
# 2         NaN                     MF                        W          2024
# 3         USA                    NaN                      NaN            {}
# 4         USA                    NaN                      NaN            {}
#
#   secondary_broad_position secondary_general_position
# 0                      NaN                        NaN
# 1                       MF                          W
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
#
# players/xgoals DataFrame:
#     player_id     team_id general_position  minutes_played  shots  \
# 0  0Oq60APM6D  4JMAkpDqKg               CB             148      0
# 1  0Oq6246gq6  e7MzZbKMr0               ST             144      1
# 2  0Oq62e7Xq6  NWMWg9LMlz                W              13      0
# 3  0Oq631dgQ6  2lqRjjnqr0               ST              67      1
# 4  0Oq632k7Q6  KXMe8Z2Q64               DM            1884     18
#
#    shots_on_target  goals  xgoals  xplace  goals_minus_xgoals  key_passes  \
# 0                0      0  0.0000  0.0000              0.0000           0
# 1                1      0  0.0886 -0.0229             -0.0886           3
# 2                0      0  0.0000  0.0000              0.0000           0
# 3                1      0  0.0717  0.4951             -0.0717           1
# 4                3      1  0.6692  0.3047              0.3308          21
#
#    primary_assists  xassists  primary_assists_minus_xassists  \
# 0                0    0.0000                          0.0000
# 1                1    0.2862                          0.7138
# 2                0    0.0000                          0.0000
# 3                0    0.0284                         -0.0284
# 4                1    1.1577                         -0.1577
#
#    xgoals_plus_xassists  points_added  xpoints_added
# 0                0.0000        0.0000         0.0000
# 1                0.3748        0.0000         0.0793
# 2                0.0000        0.0000         0.0000
# 3                0.1000        0.0000         0.0596
# 4                1.8269        0.0006         0.3568
#
# players/xpass DataFrame:
#     player_id     team_id general_position  minutes_played  attempted_passes  \
# 0  0Oq60APM6D  4JMAkpDqKg               CB             148                90
# 1  0Oq6246gq6  e7MzZbKMr0               ST             144                44
# 2  0Oq62e7Xq6  NWMWg9LMlz                W              13                 2
# 3  0Oq631dgQ6  2lqRjjnqr0               ST              67                12
# 4  0Oq632k7Q6  KXMe8Z2Q64               DM            1884              1296
#
#    pass_completion_percentage  xpass_completion_percentage  \
# 0                      0.9333                       0.8835
# 1                      0.6818                       0.7721
# 2                      0.5000                       0.5278
# 3                      0.8333                       0.8651
# 4                      0.7971                       0.8214
#
#    passes_completed_over_expected  passes_completed_over_expected_p100  \
# 0                          4.4895                               4.9883
# 1                         -3.9736                              -9.0308
# 2                         -0.0556                              -2.7780
# 3                         -0.3812                              -3.1770
# 4                        -31.5748                              -2.4363
#
#    avg_distance_yds  avg_vertical_distance_yds  share_team_touches  \
# 0           22.6125                     7.6299              0.0739
# 1           13.6529                     1.5407              0.0559
# 2            8.2197                     6.8425              0.0071
# 3           12.5054                    -7.6993              0.0254
# 4           21.0463                     5.4463              0.1106
#
#    count_games
# 0            2
# 1            2
# 2            1
# 3            1
# 4           22
#
# players/goals-added DataFrame:
#     player_id     team_id general_position  minutes_played  \
# 0  0Oq60APM6D  4JMAkpDqKg               CB             148
# 1  0Oq6246gq6  e7MzZbKMr0               ST             144
# 2  0Oq62e7Xq6  NWMWg9LMlz                W              13
# 3  0Oq631dgQ6  2lqRjjnqr0               ST              67
# 4  0Oq632k7Q6  KXMe8Z2Q64               DM            1884
#
#                                                 data
# 0  [{'action_type': 'Dribbling', 'goals_added_raw...
# 1  [{'action_type': 'Dribbling', 'goals_added_raw...
# 2  [{'action_type': 'Dribbling', 'goals_added_raw...
# 3  [{'action_type': 'Dribbling', 'goals_added_raw...
# 4  [{'action_type': 'Dribbling', 'goals_added_raw...
#
# goalkeepers/xgoals DataFrame:
#     player_id                               team_id  minutes_played  \
# 0  0Oq634GzQ6                            ljqEJ7OQx0            3572
# 1  0Oq6BKAq6D                            4JMAkpDqKg            1855
# 2  0Oq6ENeg56                            KPqjwN4Q6v             976
# 3  0Oq6lagAM6  [4JMAkpDqKg, EGMPr2yqaY, 9vQ2ZkaQK6]            2351
# 4  0Oq6wB7zQ6              [0Oq6332Q6D, NWMWgNDMlz]             900
#
#    shots_faced  goals_conceded  saves  share_headed_shots  xgoals_gk_faced  \
# 0          153              56     94              0.1765          49.2893
# 1          106              35     66              0.1698          38.1685
# 2           69              27     42              0.2174          21.4108
# 3          127              43     83              0.1890          39.1330
# 4           34              14     20              0.2059          14.3798
#
#    goals_minus_xgoals_gk  goals_divided_by_xgoals_gk
# 0                 6.7107                      1.1361
# 1                -3.1685                      0.9170
# 2                 5.5892                      1.2610
# 3                 3.8670                      1.0988
# 4                -0.3798                      0.9736
#
# goalkeepers/goals-added DataFrame:
#     player_id                               team_id  minutes_played  \
# 0  0Oq634GzQ6                            ljqEJ7OQx0            3572
# 1  0Oq6BKAq6D                            4JMAkpDqKg            1855
# 2  0Oq6ENeg56                            KPqjwN4Q6v             976
# 3  0Oq6lagAM6  [4JMAkpDqKg, EGMPr2yqaY, 9vQ2ZkaQK6]            2351
# 4  0Oq6wB7zQ6              [0Oq6332Q6D, NWMWgNDMlz]             900
#
#                                                 data
# 0  [{'action_type': 'Claiming', 'goals_added_raw'...
# 1  [{'action_type': 'Claiming', 'goals_added_raw'...
# 2  [{'action_type': 'Claiming', 'goals_added_raw'...
# 3  [{'action_type': 'Claiming', 'goals_added_raw'...
# 4  [{'action_type': 'Claiming', 'goals_added_raw'...
#
# teams DataFrame:
#       team_id               team_name team_short_name team_abbreviation
# 0  0OlMlzRqLz      Charleston Battery      Charleston               CHS
# 1  0Oq62Dgq6D       New Mexico United      New Mexico                NM
# 2  0Oq6332Q6D  Sacramento Republic FC      Sacramento               SAC
# 3  0Oq6JvPq6D      San Diego Loyal SC       San Diego                SD
# 4  0x5gJawM7O          Austin Bold FC          Austin               ATX
#
# teams/xgoals DataFrame:
#       team_id  count_games  shots_for  shots_against  goals_for  \
# 0  0OlMlzRqLz          229       2743           2743        325
# 1  0Oq62Dgq6D          158       1830           1846        226
# 2  0Oq6332Q6D          232       3131           2617        316
# 3  0Oq6JvPq6D          119       1490           1521        196
# 4  0x5gJawM7O           84       1119            959        113
#
#    goals_against  goal_difference  xgoals_for  xgoals_against  \
# 0            310               15    305.1940        304.1705
# 1            205               21    225.6390        206.6752
# 2            250               66    348.8246        272.0918
# 3            162               34    183.5208        164.1389
# ...
# 1                0      0  0.0000  0.0000              0.0000           0
# 2                2      1  0.7915 -0.0752              0.2085          11
# 3                0      0  0.4357 -0.4357             -0.4357           4
# 4                0      0  0.1290 -0.1290             -0.1290           0
#
#    primary_assists  xassists  primary_assists_minus_xassists  \
# 0                0    0.5044                         -0.5044
# 1                0    0.0000                          0.0000
# 2                2    0.9501                          1.0499
# 3                0    0.2282                         -0.2282
# 4                0    0.0000                          0.0000
#
#    xgoals_plus_xassists  points_added  xpoints_added
# 0                0.5688           0.0         0.0454
# 1                0.0000           0.0         0.0000
# 2                1.7416           0.0         0.4415
# 3                0.6640           0.0         0.2090
# 4                0.1290           0.0         0.1748
#
# players/xpass DataFrame:
#     player_id     team_id general_position  minutes_played  attempted_passes  \
# 0  0Oq64BXM6D  9Yqda8OQvJ               FB             744               328
# 1  0Oq6BKAq6D  odMX7YWQYL               GK            3019              1084
# 2  0Oq6la47M6  aDQ0NRP5Ev               CM            1166               499
# 3  0Oq6lE7xM6  kRQand1MKZ                W             478               187
# 4  0Oq6lj0AM6  odMX7YWQYL               CB             899               397
#
#    pass_completion_percentage  xpass_completion_percentage  \
# 0                      0.7256                       0.7629
# 1                      0.8035                       0.8004
# 2                      0.8537                       0.8433
# 3                      0.8021                       0.8166
# 4                      0.8186                       0.8340
#
#    passes_completed_over_expected  passes_completed_over_expected_p100  \
# 0                        -12.2248                              -3.7271
# 1                          3.3739                               0.3112
# 2                          5.1822                               1.0385
# 3                         -2.6971                              -1.4423
# 4                         -6.0954                              -1.5354
#
#    avg_distance_yds  avg_vertical_distance_yds  share_team_touches  \
# 0           18.4763                     6.2058              0.0622
# 1           33.5460                    22.0569              0.0627
# 2           16.8366                     0.8988              0.0552
# 3           19.0881                     0.9655              0.0499
# 4           23.7447                     9.9171              0.0879
#
#    count_games
# 0           13
# 1           31
# 2           21
# 3            9
# 4           11
#
# players/goals-added DataFrame:
#     player_id     team_id general_position  minutes_played  \
# 0  0Oq64BXM6D  9Yqda8OQvJ               FB             744
# 1  0Oq6la47M6  aDQ0NRP5Ev               CM            1166
# 2  0Oq6lE7xM6  kRQand1MKZ                W             478
# 3  0Oq6lj0AM6  odMX7YWQYL               CB             899
# 4  0Oq6lJexM6  aDQ0L0lQEv               ST             283
#
#                                                 data
# 0  [{'action_type': 'Dribbling', 'goals_added_raw...
# 1  [{'action_type': 'Dribbling', 'goals_added_raw...
# 2  [{'action_type': 'Dribbling', 'goals_added_raw...
# 3  [{'action_type': 'Dribbling', 'goals_added_raw...
# 4  [{'action_type': 'Dribbling', 'goals_added_raw...
#
# goalkeepers/xgoals DataFrame:
#     player_id     team_id  minutes_played  shots_faced  goals_conceded  saves  \
# 0  0Oq6BKAq6D  odMX7YWQYL            3019          114              33     79
# 1  2lqRkj6AQr  NPqxxzmq9d            3225          128              41     81
# 2  2vQ1N3dOMr  9Yqda8OQvJ             731           41               9     30
# 3  4JMAaogDMK  KAqBNNVqbg            5564          213              60    148
# 4  7VqGmDxxMv  2lqRjjnqr0             491           26               9     17
#
#    share_headed_shots  xgoals_gk_faced  goals_minus_xgoals_gk  \
# 0              0.2018          31.7092                 1.2908
# 1              0.1875          38.9568                 2.0432
# 2              0.0488          10.8748                -1.8748
# 3              0.1643          59.9796                 0.0204
# 4              0.0385           6.1988                 2.8012
#
#    goals_divided_by_xgoals_gk
# 0                      1.0407
# 1                      1.0524
# 2                      0.8276
# 3                      1.0003
# 4                      1.4519
#
# goalkeepers/goals-added DataFrame:
#     player_id     team_id  minutes_played  \
# 0  0Oq6BKAq6D  odMX7YWQYL            3019
# 1  2lqRkj6AQr  NPqxxzmq9d            3225
# 2  2vQ1N3dOMr  9Yqda8OQvJ             731
# 3  4JMAaogDMK  KAqBNNVqbg            5564
# 4  7VqGmDxxMv  2lqRjjnqr0             491
#
#                                                 data
# 0  [{'action_type': 'Claiming', 'goals_added_raw'...
# 1  [{'action_type': 'Claiming', 'goals_added_raw'...
# 2  [{'action_type': 'Claiming', 'goals_added_raw'...
# 3  [{'action_type': 'Claiming', 'goals_added_raw'...
# 4  [{'action_type': 'Claiming', 'goals_added_raw'...
#
# teams DataFrame:
#       team_id          team_name team_short_name team_abbreviation
# 0  2lqRjjnqr0        Indy Eleven            Indy               IND
# 1  2vQ1NowMrA  Tampa Bay Rowdies       Tampa Bay               TBR
# 2  4wM4lGgMjB  North Carolina FC  North Carolina                NC
# 3  9vQ2ZkaQK6       The Miami FC           Miami               MIA
# 4  9Yqda8OQvJ        FC Edmonton        Edmonton               EDM
#
# teams/xgoals DataFrame:
#       team_id  count_games  shots_for  shots_against  goals_for  \
# 0  2lqRjjnqr0           66        782            886         90
# 1  2vQ1NowMrA           32        435            318         38
# 2  4wM4lGgMjB           65        757            846         82
# 3  9vQ2ZkaQK6           65        719            844         98
# 4  9Yqda8OQvJ           65        692            800         49
#
#    goals_against  goal_difference  xgoals_for  xgoals_against  \
# 0             87                3     85.9476         96.6869
# 1             40               -2     42.3796         39.0044
# 2             84               -2     79.3554         85.5108
# 3             68               30     80.3026         77.0447
# 4             62              -13     69.6262         75.0742
#
#    xgoal_difference  goal_difference_minus_xgoal_difference  points  xpoints
# 0          -10.7393                                 13.7393      92   83.266
# 1            3.3752                                 -5.3752      39   45.427
# 2           -6.1554                                  4.1554      85   84.323
# 3            3.2579                                 26.7421     110   89.840
# 4           -5.4480                                 -7.5520      80   81.513
#
# teams/xpass DataFrame:
#       team_id  count_games  attempted_passes_for  \
# 0  2lqRjjnqr0           66                 27176
# 1  2vQ1NowMrA           32                 14733
# 2  4wM4lGgMjB           65                 31586
# 3  9vQ2ZkaQK6           65                 34349
# 4  9Yqda8OQvJ           65                 26623
#
#    pass_completion_percentage_for  xpass_completion_percentage_for  \
# 0                          0.7298                           0.7403
# 1                          0.7719                           0.7562
# 2                          0.7858                           0.7800
# 3                          0.8328                           0.8227
# 4                          0.7359                           0.7454
#
#    passes_completed_over_expected_for  \
# 0                           -284.6813
# 1                            231.2274
# 2                            181.3380
# 3                            345.6118
# 4                           -255.0743
#
#    passes_completed_over_expected_p100_for  avg_vertical_distance_for  \
# 0                                  -1.0475                     9.3471
# 1                                   1.5695                     7.9674
# 2                                   0.5741                     7.5667
# 3                                   1.0062                     5.7035
# 4                                  -0.9581                     9.1815
#
#    attempted_passes_against  pass_completion_percentage_against  \
# 0                     30549                              0.7704
# 1                     13014                              0.7456
# 2                     29914                              0.7776
# 3                     27293                              0.7807
# 4                     30835                              0.7758
#
#    xpass_completion_percentage_against  \
# 0                               0.7654
# 1                               0.7593
# 2                               0.7734
# 3                               0.7752
# 4                               0.7741
#
#    passes_completed_over_expected_against  \
# 0                                151.0264
# 1                               -178.5410
# 2                                124.1578
# 3                                151.5859
# 4                                 54.6181
#
#    passes_completed_over_expected_p100_against  avg_vertical_distance_against  \
# 0                                       0.4944                         8.0280
# 1                                      -1.3719                         9.2561
# 2                                       0.4150                         7.6430
# 3                                       0.5554                         7.5684
# 4                                       0.1771                         7.6009
#
#    passes_completed_over_expected_difference  avg_vertical_distance_difference
# 0                                  -435.7077                            1.3191
# 1                                   409.7685                           -1.2887
# 2                                    57.1802                           -0.0763
# 3                                   194.0259                           -1.8649
# 4                                  -309.6923                            1.5806
#
# teams/goals-added DataFrame:
#       team_id  minutes                                               data
# 0  2lqRjjnqr0     6535  [{'action_type': 'Interrupting', 'num_actions_...
# 1  2vQ1NowMrA     3158  [{'action_type': 'Claiming', 'num_actions_for'...
# 2  4wM4lGgMjB     6412  [{'action_type': 'Claiming', 'num_actions_for'...
# 3  9vQ2ZkaQK6     6446  [{'action_type': 'Dribbling', 'num_actions_for...
# 4  9Yqda8OQvJ     6385  [{'action_type': 'Dribbling', 'num_actions_for...
#
# games DataFrame:
#       game_id            date_time_utc  home_score  away_score home_team_id  \
# 0  a35r77O2qL  2017-11-13 01:00:00 UTC           2           0   gpMOeARqzy
# 1  vzqoxx3vQa  2017-11-06 01:00:00 UTC           1           0   gpMOeARqzy
# 2  gpMOGGERMz  2017-11-05 22:00:00 UTC           0           0   9vQ2ZkaQK6
# 3  p6qbxzG8M0  2017-10-29 21:00:00 UTC           2           2   2lqRjjnqr0
# 4  XVqKO7JKq0  2017-10-29 01:00:00 UTC           0           2   gpMOeARqzy
#
#   away_team_id  referee_id  stadium_id home_manager_id away_manager_id  \
# 0   KAqBNNVqbg  ljqExYw5x0  9vQ29NoqK6      0Oq6mxd56D      gpMOYv1qzy
# 1   4wM4lGgMjB  KPqjDeNM6v  9vQ29NoqK6      0Oq6mxd56D      vzqoWWYqap
# 2   KAqBNNVqbg  0Oq6vG2q6D  odMXRaaqYL      KAqBEjX5bg      gpMOYv1qzy
# 3   4wM4lGgMjB  Xj5YrBaqbd  jYQJazGqGR      9vQ2AGmqK6      vzqoWWYqap
# 4   odMX7YWQYL  0Oq6mXx56D  9vQ29NoqK6      0Oq6mxd56D      9vQ2mn7qK6
#
#    expanded_minutes season_name  matchday  attendance  knockout_game  \
# 0               100        2017         2        9691           True
# 1                98        2017         1        3586           True
# 2               129        2017         1        7115           True
# 3                96        2017        37        8813          False
# 4                97        2017        37        4755          False
#
#           last_updated_utc extra_time penalties  home_penalties  \
# 0  2017-11-15 14:53:53 UTC        NaN       NaN             NaN
# 1  2017-11-10 14:05:31 UTC        NaN       NaN             NaN
# 2  2017-11-09 15:24:22 UTC       True      True             5.0
# 3  2017-11-06 15:11:42 UTC        NaN       NaN             NaN
# 4  2017-11-03 17:32:19 UTC        NaN       NaN             NaN
#
#    away_penalties
# 0             NaN
# 1             NaN
# 2             6.0
# 3             NaN
# 4             NaN
#
# games/xgoals DataFrame:
#       game_id            date_time_utc home_team_id  home_goals  \
# 0  a35r77O2qL  2017-11-13 01:00:00 UTC   gpMOeARqzy           2
# 1  vzqoxx3vQa  2017-11-06 01:00:00 UTC   gpMOeARqzy           1
# 2  gpMOGGERMz  2017-11-05 22:00:00 UTC   9vQ2ZkaQK6           0
# 3  p6qbxzG8M0  2017-10-29 21:00:00 UTC   2lqRjjnqr0           2
# 4  XVqKO7JKq0  2017-10-29 01:00:00 UTC   gpMOeARqzy           0
#
#    home_team_xgoals  home_player_xgoals away_team_id  away_goals  \
# 0            2.8509              2.8653   KAqBNNVqbg           0
# 1            0.3735              0.3735   4wM4lGgMjB           0
# 2            1.5929              1.5929   KAqBNNVqbg           0
# 3            1.4060              1.4060   4wM4lGgMjB           2
# 4            0.8354              0.8357   odMX7YWQYL           2
#
#    away_team_xgoals  away_player_xgoals  goal_difference  \
# 0            1.7994              1.8083                2
# 1            0.4259              0.4259                1
# 2            0.5951              0.5965                0
# 3            0.9158              0.9413                0
# 4            0.7109              0.7161               -2
#
#    team_xgoal_difference  player_xgoal_difference  final_score_difference  \
# 0                 1.0515                   1.0570                       2
# 1                -0.0523                  -0.0523                       1
# 2                 0.9979                   0.9964                       0
# 3                 0.4902                   0.4647                       0
# 4                 0.1245                   0.1197                      -2
#
#    home_xpoints  away_xpoints
# 0         0.000         0.000
# 1         0.000         0.000
# 2         0.000         0.000
# 3         1.800         0.903
# 4         1.433         1.196
#
# managers DataFrame:
#    manager_id        manager_name nationality
# 0  0Oq6mjP56D          Gerard Nus       Spain
# 1  0Oq6mxd56D     Marc Dos Santos      Canada
# 2  0x5gyP7Q7O       Paul Dalglish    Scotland
# 3  7VqGE1eMvW  Phillip Dos Santos         NaN
# 4  7VqGEmAMvW        Alen Marcina      Canada
#
# referees DataFrame:
#    referee_id        referee_name nationality birth_date
# 0  0Oq6mnX56D     Michael Radchuk         USA        NaN
# 1  0Oq6mXx56D       Farhad Dadkho         USA        NaN
# 2  0Oq6vG2q6D  Marcos de Oliveira         USA        NaN
# 3  2lqRNx4qr0        Geoff Gamble         USA        NaN
# 4  2lqRymD5r0        Victor Rivas         USA        NaN
#
# stadia DataFrame:
#    stadium_id                    stadium_name  year_built street city  \
# 0  0Oq6E4A56D   Central Broward Regional Park         NaN    NaN  NaN
# 1  0Oq6LExM6D              Hodges Stadium UNF         NaN    NaN  NaN
# 2  315VPyVQ9x  National Sports Center Stadium         NaN    NaN  NaN
# 3  7VqG0jdQvW         James M. Shuart Stadium         NaN    NaN  NaN
# 4  9vQ29NoqK6                   Kezar Stadium         NaN    NaN  NaN
#
#   province country postal_code
# 0      NaN     NaN         NaN
# 1      NaN     NaN         NaN
# 2      NaN     NaN         NaN
# 3      NaN     NaN         NaN
# 4      NaN     NaN         NaN

# %%
directory = 'data'

# save each dataframe as a csv
for league, dataframes in league_dfs.items():
    for endpoint, df in dataframes.items():
        # Replace any '/' in endpoint name as it's not allowed in file names
        endpoint = endpoint.replace('/', '_')
        filename = f"{directory}/{league}_{endpoint}.csv"
        df.to_csv(filename, index=False)
        print(f"DataFrame for {league} - {endpoint} saved as {filename}")
# Out:
# DataFrame for MLS - players saved as data/MLS_players.csv
# DataFrame for MLS - players_xgoals saved as data/MLS_players_xgoals.csv
# DataFrame for MLS - players_xpass saved as data/MLS_players_xpass.csv
# DataFrame for MLS - players_goals-added saved as data/MLS_players_goals-added.csv
# DataFrame for MLS - players_salaries saved as data/MLS_players_salaries.csv
# DataFrame for MLS - goalkeepers_xgoals saved as data/MLS_goalkeepers_xgoals.csv
# DataFrame for MLS - goalkeepers_goals-added saved as data/MLS_goalkeepers_goals-added.csv
# DataFrame for MLS - teams saved as data/MLS_teams.csv
# DataFrame for MLS - teams_xgoals saved as data/MLS_teams_xgoals.csv
# DataFrame for MLS - teams_xpass saved as data/MLS_teams_xpass.csv
# DataFrame for MLS - teams_goals-added saved as data/MLS_teams_goals-added.csv
# DataFrame for MLS - games saved as data/MLS_games.csv
# DataFrame for MLS - games_xgoals saved as data/MLS_games_xgoals.csv
# DataFrame for MLS - managers saved as data/MLS_managers.csv
# DataFrame for MLS - referees saved as data/MLS_referees.csv
# DataFrame for MLS - stadia saved as data/MLS_stadia.csv
# DataFrame for NWSL - players saved as data/NWSL_players.csv
# DataFrame for NWSL - players_xgoals saved as data/NWSL_players_xgoals.csv
# DataFrame for NWSL - players_xpass saved as data/NWSL_players_xpass.csv
# DataFrame for NWSL - players_goals-added saved as data/NWSL_players_goals-added.csv
# DataFrame for NWSL - goalkeepers_xgoals saved as data/NWSL_goalkeepers_xgoals.csv
# DataFrame for NWSL - goalkeepers_goals-added saved as data/NWSL_goalkeepers_goals-added.csv
# DataFrame for NWSL - teams saved as data/NWSL_teams.csv
# DataFrame for NWSL - teams_xgoals saved as data/NWSL_teams_xgoals.csv
# DataFrame for NWSL - teams_xpass saved as data/NWSL_teams_xpass.csv
# DataFrame for NWSL - teams_goals-added saved as data/NWSL_teams_goals-added.csv
# DataFrame for NWSL - games saved as data/NWSL_games.csv
# DataFrame for NWSL - games_xgoals saved as data/NWSL_games_xgoals.csv
# DataFrame for NWSL - managers saved as data/NWSL_managers.csv
# DataFrame for NWSL - referees saved as data/NWSL_referees.csv
# DataFrame for NWSL - stadia saved as data/NWSL_stadia.csv
# DataFrame for USLC - players saved as data/USLC_players.csv
# DataFrame for USLC - players_xgoals saved as data/USLC_players_xgoals.csv
# DataFrame for USLC - players_xpass saved as data/USLC_players_xpass.csv
# DataFrame for USLC - players_goals-added saved as data/USLC_players_goals-added.csv
# DataFrame for USLC - goalkeepers_xgoals saved as data/USLC_goalkeepers_xgoals.csv
# DataFrame for USLC - goalkeepers_goals-added saved as data/USLC_goalkeepers_goals-added.csv
# DataFrame for USLC - teams saved as data/USLC_teams.csv
# DataFrame for USLC - teams_xgoals saved as data/USLC_teams_xgoals.csv
# DataFrame for USLC - teams_xpass saved as data/USLC_teams_xpass.csv
# DataFrame for USLC - teams_goals-added saved as data/USLC_teams_goals-added.csv
# DataFrame for USLC - games saved as data/USLC_games.csv
# DataFrame for USLC - games_xgoals saved as data/USLC_games_xgoals.csv
# DataFrame for USLC - managers saved as data/USLC_managers.csv
# DataFrame for USLC - referees saved as data/USLC_referees.csv
# DataFrame for USLC - stadia saved as data/USLC_stadia.csv
# DataFrame for USL1 - players saved as data/USL1_players.csv
# DataFrame for USL1 - players_xgoals saved as data/USL1_players_xgoals.csv
# DataFrame for USL1 - players_xpass saved as data/USL1_players_xpass.csv
# DataFrame for USL1 - players_goals-added saved as data/USL1_players_goals-added.csv
# DataFrame for USL1 - goalkeepers_xgoals saved as data/USL1_goalkeepers_xgoals.csv
# DataFrame for USL1 - goalkeepers_goals-added saved as data/USL1_goalkeepers_goals-added.csv
# DataFrame for USL1 - teams saved as data/USL1_teams.csv
# DataFrame for USL1 - teams_xgoals saved as data/USL1_teams_xgoals.csv
# DataFrame for USL1 - teams_xpass saved as data/USL1_teams_xpass.csv
# DataFrame for USL1 - teams_goals-added saved as data/USL1_teams_goals-added.csv
# DataFrame for USL1 - games saved as data/USL1_games.csv
# DataFrame for USL1 - games_xgoals saved as data/USL1_games_xgoals.csv
# DataFrame for USL1 - managers saved as data/USL1_managers.csv
# DataFrame for USL1 - referees saved as data/USL1_referees.csv
# DataFrame for USL1 - stadia saved as data/USL1_stadia.csv
# DataFrame for MLSNP - players saved as data/MLSNP_players.csv
# DataFrame for MLSNP - players_xgoals saved as data/MLSNP_players_xgoals.csv
# DataFrame for MLSNP - players_xpass saved as data/MLSNP_players_xpass.csv
# DataFrame for MLSNP - players_goals-added saved as data/MLSNP_players_goals-added.csv
# DataFrame for MLSNP - goalkeepers_xgoals saved as data/MLSNP_goalkeepers_xgoals.csv
# DataFrame for MLSNP - goalkeepers_goals-added saved as data/MLSNP_goalkeepers_goals-added.csv
# DataFrame for MLSNP - teams saved as data/MLSNP_teams.csv
# DataFrame for MLSNP - teams_xgoals saved as data/MLSNP_teams_xgoals.csv
# DataFrame for MLSNP - teams_xpass saved as data/MLSNP_teams_xpass.csv
# DataFrame for MLSNP - teams_goals-added saved as data/MLSNP_teams_goals-added.csv
# DataFrame for MLSNP - games saved as data/MLSNP_games.csv
# DataFrame for MLSNP - games_xgoals saved as data/MLSNP_games_xgoals.csv
# DataFrame for MLSNP - managers saved as data/MLSNP_managers.csv
# DataFrame for MLSNP - referees saved as data/MLSNP_referees.csv
# DataFrame for MLSNP - stadia saved as data/MLSNP_stadia.csv
# DataFrame for NASL - players saved as data/NASL_players.csv
# DataFrame for NASL - players_xgoals saved as data/NASL_players_xgoals.csv
# DataFrame for NASL - players_xpass saved as data/NASL_players_xpass.csv
# DataFrame for NASL - players_goals-added saved as data/NASL_players_goals-added.csv
# DataFrame for NASL - goalkeepers_xgoals saved as data/NASL_goalkeepers_xgoals.csv
# DataFrame for NASL - goalkeepers_goals-added saved as data/NASL_goalkeepers_goals-added.csv
# DataFrame for NASL - teams saved as data/NASL_teams.csv
# DataFrame for NASL - teams_xgoals saved as data/NASL_teams_xgoals.csv
# DataFrame for NASL - teams_xpass saved as data/NASL_teams_xpass.csv
# DataFrame for NASL - teams_goals-added saved as data/NASL_teams_goals-added.csv
# DataFrame for NASL - games saved as data/NASL_games.csv
# DataFrame for NASL - games_xgoals saved as data/NASL_games_xgoals.csv
# DataFrame for NASL - managers saved as data/NASL_managers.csv
# DataFrame for NASL - referees saved as data/NASL_referees.csv
# DataFrame for NASL - stadia saved as data/NASL_stadia.csv

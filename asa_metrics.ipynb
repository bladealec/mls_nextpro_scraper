# %%
import pandas as pd

# %%
file_names = [
    "MLSNP_players", "MLSNP_players_xgoals", "MLSNP_players_xpass", 
    "MLSNP_players_goals-added", "MLSNP_goalkeepers_xgoals", 
    "MLSNP_goalkeepers_goals-added", "MLSNP_teams", 
    "MLSNP_teams_xgoals", "MLSNP_teams_xpass", 
    "MLSNP_teams_goals-added", "MLSNP_games", "MLSNP_games_xgoals", 
    "MLSNP_managers", "MLSNP_referees", "MLSNP_stadia"
]

# %%
# load each csv into dataframes
data_frames = {}
for file_name in file_names:
    file_path = f"data/{file_name}.csv"
    data_frames[file_name] = pd.read_csv(file_path)

# %%
data_frames['MLSNP_players']
# Out:
#       player_id          player_name nationality primary_broad_position  \
# 0    0Oq624kdq6  Christopher Rodgers         USA                     DF
# 1    0Oq624oPq6  Kalani Kossa-Rienzi         USA                     MF
# 2    0Oq62blzq6  Christian Tchouante    Cameroon                    NaN
# 3    0Oq62L42q6               Thiago      Brazil                     FW
# 4    0Oq62O1rq6        Robert Bailey         USA                    NaN
# ..          ...                  ...         ...                    ...
# 995  KAqBkZ1vQb          David Duque         USA                     MF
# 996  KAqBkZyvQb          Noah Santos         USA                     FW
# 997  KAqBNbaWqb       Efrain Morales         USA                     DF
# 998  KAqBNEB7qb      Kieran Sargeant         USA                     FW
# 999  KAqBNkeWqb      Christian Koffi      France                     MF
#
#     primary_general_position       season_name  birth_date  height_ft  \
# 0                         CB              2023         NaN        NaN
# 1                          W              2024  2002-06-27        5.0
# 2                        NaN                {}  2006-01-17        NaN
# 3                          W              2023  2003-03-06        NaN
# 4                        NaN                {}  2000-05-19        NaN
# ..                       ...               ...         ...        ...
# 995                       CM              2023  2006-06-21        NaN
# 996                       ST  ['2023', '2024']  2007-01-10        NaN
# 997                       CB  ['2023', '2024']  2004-03-04        6.0
# 998                        W              2024  2003-05-15        NaN
# 999                        W              2024  2000-08-28        5.0
#
#      height_in  weight_lb secondary_general_position secondary_broad_position
# 0          NaN        NaN                        NaN                      NaN
# 1          8.0      150.0                        NaN                      NaN
# 2          NaN        NaN                        NaN                      NaN
# 3          NaN        NaN                        NaN                      NaN
# 4          NaN        NaN                        NaN                      NaN
# ..         ...        ...                        ...                      ...
# 995        NaN        NaN                        NaN                      NaN
# 996        NaN        NaN                        NaN                      NaN
# 997        3.0      170.0                        NaN                      NaN
# 998        NaN        NaN                         CB                       DF
# 999        8.0        NaN                        NaN                      NaN
#
# [1000 rows x 12 columns]

# %%
for i in data_frames:
    print(i)
    print(data_frames[i].head(2))
# Out:
# MLSNP_players
#     player_id          player_name nationality primary_broad_position  \
# 0  0Oq624kdq6  Christopher Rodgers         USA                     DF
# 1  0Oq624oPq6  Kalani Kossa-Rienzi         USA                     MF
#
#   primary_general_position season_name  birth_date  height_ft  height_in  \
# 0                       CB        2023         NaN        NaN        NaN
# 1                        W        2024  2002-06-27        5.0        8.0
#
#    weight_lb secondary_general_position secondary_broad_position
# 0        NaN                        NaN                      NaN
# 1      150.0                        NaN                      NaN
# MLSNP_players_xgoals
#     player_id     team_id general_position  minutes_played  shots  \
# 0  0Oq624kdq6  0Oq6Yad56D               CB            1214      4
# 1  0Oq624oPq6  KXMe8Z2Q64                W             307      7
#
#    shots_on_target  goals  xgoals  xplace  goals_minus_xgoals  key_passes  \
# 0                1      0  0.1802 -0.1250             -0.1802           2
# 1                1      0  0.3831 -0.3384             -0.3831           5
#
#    primary_assists  xassists  primary_assists_minus_xassists  \
# 0                0    0.1576                         -0.1576
# 1                2    0.6697                          1.3303
#
#    xgoals_plus_xassists  points_added  xpoints_added
# 0                0.3377           0.0         0.1310
# 1                1.0528           0.0         0.0867
# MLSNP_players_xpass
#     player_id     team_id general_position  minutes_played  attempted_passes  \
# 0  0Oq624kdq6  0Oq6Yad56D               CB            1214               684
# 1  0Oq624oPq6  KXMe8Z2Q64                W             307               188
#
#    pass_completion_percentage  xpass_completion_percentage  \
# 0                      0.8582                       0.8463
# 1                      0.8351                       0.8124
#
#    passes_completed_over_expected  passes_completed_over_expected_p100  \
# 0                          8.1036                               1.1847
# 1                          4.2675                               2.2699
#
#    avg_distance_yds  avg_vertical_distance_yds  share_team_touches  \
# 0           21.0481                     7.5001              0.0723
# 1           18.8125                     0.8436              0.1094
#
#    count_games
# 0           16
# 1            3
# MLSNP_players_goals-added
#     player_id     team_id general_position  minutes_played  \
# 0  0Oq624kdq6  0Oq6Yad56D               CB            1214
# 1  0Oq624oPq6  KXMe8Z2Q64                W             307
#
#                                                 data
# 0  [{'action_type': 'Dribbling', 'goals_added_raw...
# 1  [{'action_type': 'Dribbling', 'goals_added_raw...
# MLSNP_goalkeepers_xgoals
#     player_id     team_id  minutes_played  shots_faced  goals_conceded  saves  \
# 0  0Oq62Y3zq6  a35reDLML6            1879           66              25     41
# 1  0Oq6ErR256  a35reDLML6             296            7               4      3
#
#    share_headed_shots  xgoals_gk_faced  goals_minus_xgoals_gk  \
# 0              0.1212          22.5282                 2.4718
# 1              0.0000           3.4603                 0.5397
#
#    goals_divided_by_xgoals_gk
# 0                      1.1097
# 1                      1.1560
# MLSNP_goalkeepers_goals-added
#     player_id     team_id  minutes_played  \
# 0  0Oq62Y3zq6  a35reDLML6            1879
# 1  0Oq6ErR256  a35reDLML6             296
#
#                                                 data
# 0  [{'action_type': 'Claiming', 'goals_added_raw'...
# 1  [{'action_type': 'Claiming', 'goals_added_raw'...
# MLSNP_teams
#       team_id           team_name team_short_name team_abbreviation
# 0  0Oq6Yad56D     Columbus Crew 2        Columbus               CLB
# 1  0x5gb3bM7O  Chicago Fire FC II         Chicago               CHI
# MLSNP_teams_xgoals
#       team_id  count_games  shots_for  shots_against  goals_for  \
# 0  0Oq6Yad56D           62        894            738        141
# 1  0x5gb3bM7O           55        811            742         98
#
#    goals_against  goal_difference  xgoals_for  xgoals_against  \
# 0             84               57    124.8680         83.1018
# 1             94                4     88.8031         93.3001
#
#    xgoal_difference  goal_difference_minus_xgoal_difference  points  xpoints
# 0           41.7661                                 15.2339     126   96.392
# 1           -4.4970                                  8.4970      69   74.329
# MLSNP_teams_xpass
#       team_id  count_games  attempted_passes_for  \
# 0  0Oq6Yad56D           62                 34754
# 1  0x5gb3bM7O           55                 26331
#
#    pass_completion_percentage_for  xpass_completion_percentage_for  \
# 0                          0.8354                           0.8240
# 1                          0.7793                           0.7853
#
#    passes_completed_over_expected_for  \
# 0                            396.3591
# 1                           -156.4676
#
#    passes_completed_over_expected_p100_for  avg_vertical_distance_for  \
# 0                                   1.1405                     5.2466
# 1                                  -0.5942                     6.7301
#
#    attempted_passes_against  pass_completion_percentage_against  \
# 0                     30309                              0.8151
# 1                     24300                              0.7589
#
#    xpass_completion_percentage_against  \
# 0                               0.8196
# 1                               0.7800
#
#    passes_completed_over_expected_against  \
# 0                               -136.9458
# 1                               -513.0992
#
#    passes_completed_over_expected_p100_against  avg_vertical_distance_against  \
# 0                                      -0.4518                         5.9117
# 1                                      -2.1115                         7.3933
#
#    passes_completed_over_expected_difference  avg_vertical_distance_difference
# 0                                   533.3049                           -0.6651
# 1                                   356.6316                           -0.6632
# MLSNP_teams_goals-added
#       team_id  minutes                                               data
# 0  0Oq6Yad56D     6232  [{'action_type': 'Receiving', 'num_actions_for...
# 1  0x5gb3bM7O     5570  [{'action_type': 'Shooting', 'num_actions_for'...
# MLSNP_games
#       game_id            date_time_utc  home_score  away_score home_team_id  \
# 0  0x5gzNGZM7  2024-04-02 22:00:00 UTC           0           2   kRQaW3L5KZ
# 1  KAqBo3W4Qb  2024-04-01 00:00:00 UTC           1           1   7VqG1oWMvW
#
#   away_team_id  referee_id  stadium_id home_manager_id away_manager_id  \
# 0   vzqowoZqap  0Oq6AZ756D  KAqBkemQbg      vzqo4KNQap      OlMl4ADMLz
# 1   2vQ1XzlqrA  jYQJlGW5GR  9z5ka6gQA3      2lqRGzWQr0      4wM4mdN5jB
#
#    expanded_minutes  season_name  matchday  attendance  knockout_game  \
# 0                98         2024         4           0          False
# 1               101         2024         3           0          False
#
#           last_updated_utc penalties  home_penalties  away_penalties  \
# 0  2024-04-03 04:32:33 UTC       NaN             NaN             NaN
# 1  2024-04-01 02:15:53 UTC      True             3.0             4.0
#
#   extra_time
# 0        NaN
# 1        NaN
# MLSNP_games_xgoals
#       game_id            date_time_utc home_team_id  home_goals  \
# 0  0x5gzNGZM7  2024-04-02 22:00:00 UTC   kRQaW3L5KZ           0
# 1  KAqBo3W4Qb  2024-04-01 00:00:00 UTC   7VqG1oWMvW           1
#
#    home_team_xgoals  home_player_xgoals away_team_id  away_goals  \
# 0            1.8271              1.8672   vzqowoZqap           2
# 1            1.3501              1.3501   2vQ1XzlqrA           1
#
#    away_team_xgoals  away_player_xgoals  goal_difference  \
# 0            0.9215              0.9231               -2
# 1            0.6120              0.6120                0
#
#    team_xgoal_difference  player_xgoal_difference  final_score_difference  \
# 0                 0.9056                   0.9441                      -2
# 1                 0.7382                   0.7382                       0
#
#    home_xpoints  away_xpoints
# 0         2.087         0.692
# 1         2.047         0.646
# MLSNP_managers
#    manager_id      manager_name nationality
# 0  0Oq6bV6q6D     Enrique Duran       Spain
# 1  2lqRE225r0  Marcelo Neveleff   Argentina
# MLSNP_referees
#    referee_id        referee_name  birth_date nationality
# 0  0Oq67LgQ6D      Aubrey Kotelko  1994-07-30      Canada
# 1  0Oq6AZ756D  Ekaterina Koroleva         NaN         USA
# MLSNP_stadia
#    stadium_id     stadium_name  capacity  year_built   roof   turf  \
# 0  0x5g6ojM7O      PNC Stadium   22039.0      2012.0  False  False
# 1  0x5gJZjM7O  DRV PNK Stadium   18000.0      2020.0  False  False
#
#                 street             city province country postal_code  \
# 0    2200 Texas Avenue          Houston    Texas     USA       77590
# 1  1350 NW 55th Street  Fort Lauderdale  Florida     USA       33309
#
#    latitude  longitude  field_x  field_y
# 0   29.7522   -95.3524    115.0     73.0
# 1   26.1931   -80.1611      NaN      NaN

# %% [markdown]
# ## Team Performance Metrics:
# 1. Goal Difference: Calculate the difference between goals scored and goals conceded.
# 2. Expected Goals (xGoals): Compare actual goals scored/conceded with expected goals to assess finishing and defensive capabilities.
# 3. Pass Completion Percentage: Measure the accuracy of passing.
# 4. Points Earned: Directly indicates team success in matches.
#
# ## Player Performance Metrics:
# 1. Goals Scored: Traditional measure of attacking prowess.
# 2. Expected Goals (xGoals) for Attackers: To evaluate finishing ability.
# 3. Pass Completion Percentage: Indicates passing accuracy and involvement in build-up play.
# 4. Assists: Measure of creative ability.
# 5. Defensive Contributions: For defenders and midfielders, consider metrics like interceptions, tackles won, and clearances.
# 6. Goalkeeper Metrics: Save percentage, goals conceded, and expected goals conceded.

# %%
team_metrics = pd.merge(data_frames['MLSNP_teams'], data_frames['MLSNP_teams_xgoals'], on='team_id')
team_metrics = pd.merge(team_metrics, data_frames['MLSNP_teams_xpass'], on='team_id')

# team metrics
team_metrics['goal_difference'] = team_metrics['goals_for'] - team_metrics['goals_against']
team_metrics['xgoal_difference'] = team_metrics['xgoals_for'] - team_metrics['xgoals_against']
team_metrics['points_difference'] = team_metrics['points'] - team_metrics['xpoints']
team_metrics['pass_accuracy_difference'] = team_metrics['pass_completion_percentage_for'] - team_metrics['xpass_completion_percentage_for']

# classification of teams
team_metrics['team_performance'] = 'Good'
team_metrics.loc[team_metrics['goal_difference'] < 0, 'team_performance'] = 'Bad'
team_metrics.loc[team_metrics['points_difference'] < 0, 'team_performance'] = 'Bad'
team_metrics.loc[team_metrics['pass_accuracy_difference'] < 0, 'team_performance'] = 'Bad'

print(team_metrics)
# Out:
#        team_id                  team_name   team_short_name team_abbreviation  \
# 0   0Oq6Yad56D            Columbus Crew 2          Columbus               CLB
# 1   0x5gb3bM7O         Chicago Fire FC II           Chicago               CHI
# 2   2lqRX1AMr0      Minnesota United FC 2         Minnesota               MIN
# 3   2vQ14GKqrA    Sporting Kansas City II       Kansas City               SKC
# 4   2vQ1XzlqrA           Los Angeles FC 2  Los Angeles FC 2              LAFC
# 5   4JMAkpDqKg              Toronto FC II           Toronto               TOR
# 6   4wM4E4d5jB               LA Galaxy II      LA Galaxy II               LAG
# 7   7VqG1oWMvW          Colorado Rapids 2          Colorado               COL
# 8   9Yqdwg85vJ      New York Red Bulls II          New York              NYRB
# 9   a35reDLML6            Crown Legacy FC         Charlotte               CLT
# 10  BLMv6m3Mxe              Real Monarchs     Real Monarchs               SLC
# 11  eV5Dw4EMKn               Austin FC II            Austin               ATX
# 12  eVq3Z0D5WO        St. Louis City SC 2         St. Louis               STL
# 13  gOMnJnOMwN        Houston Dynamo FC 2           Houston               HOU
# 14  gpMO1Pyqzy  New England Revolution II       New England               NER
# 15  gpMOXy25zy            FC Cincinnati 2        Cincinnati               CIN
# 16  jYQJXkP5GR        New York City FC II     New York City               NYC
# 17  KPqj6bBq6v      Rochester New York FC         Rochester               ROC
# 18  KPqjwN4Q6v      Philadelphia Union II      Philadelphia               PHI
# 19  kRQaW3L5KZ             Orlando City B      Orlando City               ORL
# 20  KXMe8Z2Q64            Tacoma Defiance            Tacoma               TAC
# 21  ljqE94Vqx0             North Texas SC       North Texas               NTX
# 22  N6MmWV0qEG   Vancouver Whitecaps FC 2         Vancouver               VAN
# 23  NWMWJezQlz              Carolina Core          Carolina              CCFC
# 24  Oa5wDy8q14    San Jose Earthquakes II          San Jose               SJE
# 25  OlMlKDEQLz         Huntsville City FC        Huntsville               HNT
# 26  raMyeZAMd2             Chattanooga FC       Chattanooga               CFC
# 27  vzqowoZqap          Inter Miami CF II             Miami               MIA
# 28  wvq9jx1QWn           Atlanta United 2           Atlanta               ATL
# 29  zeQZe4DqKw         Portland Timbers 2          Portland               POR
#
#     count_games_x  shots_for  shots_against  goals_for  goals_against  \
# 0              62        894            738        141             84
# 1              55        811            742         98             94
# 2              54        864            691         94             94
# 3              55        695            743         89             86
# 4              31        394            335         40             42
# 5              55        642            710         91             97
# 6              31        357            472         46             76
# 7              55        738            678        103             91
# 8              33        468            365         66             43
# 9              31        478            310         63             38
# 10             52        545            665         55             99
# 11             34        404            366         47             26
# 12             58        880            608        105             81
# 13             55        745            685         89             71
# 14             57        742            818         87             86
# 15             55        592            882         63            135
# 16             54        782            619        111             94
# 17             25        310            259         38             34
# 18             57        830            716        102            102
# 19             56        739            852        100            119
# 20             57        633            762        122             75
# 21             54        659            724         90             75
# 22             55        664            797         80             93
# 23              3         48             36          2              7
# 24             56        751            645         93             77
# 25             31        456            337         54             51
# 26              3         31             46          6              3
# 27             55        570            877         81            119
# 28             30        324            437         54             52
# 29             55        672            803         68            134
#
#     goal_difference  ...  pass_completion_percentage_against  \
# 0                57  ...                              0.8151
# 1                 4  ...                              0.7589
# 2                 0  ...                              0.7831
# 3                 3  ...                              0.8069
# 4                -2  ...                              0.8020
# 5                -6  ...                              0.8281
# 6               -30  ...                              0.8340
# 7                12  ...                              0.8104
# 8                23  ...                              0.7667
# 9                25  ...                              0.8029
# 10              -44  ...                              0.8082
# 11               21  ...                              0.8084
# 12               24  ...                              0.7555
# 13               18  ...                              0.7785
# 14                1  ...                              0.8129
# 15              -72  ...                              0.7985
# 16               17  ...                              0.7803
# 17                4  ...                              0.7857
# 18                0  ...                              0.8088
# 19              -19  ...                              0.8041
# 20               47  ...                              0.8072
# 21               15  ...                              0.8066
# 22              -13  ...                              0.8149
# 23               -5  ...                              0.7908
# 24               16  ...                              0.7899
# 25                3  ...                              0.8219
# 26                3  ...                              0.7928
# 27              -38  ...                              0.8223
# 28                2  ...                              0.8315
# 29              -66  ...                              0.8262
#
#     xpass_completion_percentage_against  \
# 0                                0.8196
# 1                                0.7800
# 2                                0.7924
# 3                                0.8036
# 4                                0.8098
# 5                                0.8155
# 6                                0.8183
# 7                                0.8113
# 8                                0.7922
# 9                                0.8058
# 10                               0.8076
# 11                               0.8130
# 12                               0.7826
# 13                               0.7871
# 14                               0.8004
# 15                               0.7886
# 16                               0.7896
# 17                               0.7963
# 18                               0.8133
# 19                               0.7967
# 20                               0.8101
# 21                               0.8058
# 22                               0.8104
# 23                               0.8105
# 24                               0.7979
# 25                               0.8164
# 26                               0.8080
# 27                               0.8118
# 28                               0.8108
# 29                               0.8185
#
#     passes_completed_over_expected_against  \
# 0                                -136.9458
# 1                                -513.0992
# 2                                -234.6827
# 3                                  88.1075
# 4                                -115.9992
# 5                                 359.3570
# 6                                 230.4709
# 7                                 -23.8658
# 8                                -431.4494
# 9                                 -38.9299
# 10                                 15.6094
# 11                                -70.6362
# 12                               -743.8765
# 13                               -208.1385
# 14                                335.6566
# 15                                254.1869
# 16                               -208.3809
# 17                               -122.0327
# 18                               -137.6645
# 19                                181.9653
# 20                                -83.2109
# 21                                 18.0099
# 22                                121.0700
# 23                                -28.3226
# 24                               -201.5938
# 25                                 85.3840
# 26                                -23.1812
# 27                                275.7640
# 28                                302.2682
# 29                                222.5672
#
#     passes_completed_over_expected_p100_against  \
# 0                                       -0.4518
# 1                                       -2.1115
# 2                                       -0.9288
# 3                                        0.3303
# 4                                       -0.7832
# 5                                        1.2559
# 6                                        1.5737
# 7                                       -0.0928
# 8                                       -2.5548
# 9                                       -0.2864
# 10                                       0.0597
# 11                                      -0.4656
# 12                                      -2.7028
# 13                                      -0.8512
# 14                                       1.2544
# 15                                       0.9897
# 16                                      -0.9339
# 17                                      -1.0531
# 18                                      -0.4448
# 19                                       0.7459
# 20                                      -0.2906
# 21                                       0.0746
# 22                                       0.4438
# 23                                      -1.9751
# 24                                      -0.8027
# 25                                       0.5484
# 26                                      -1.5201
# 27                                       1.0436
# 28                                       2.0633
# 29                                       0.7703
#
#     avg_vertical_distance_against  passes_completed_over_expected_difference  \
# 0                          5.9117                                   533.3049
# 1                          7.3933                                   356.6316
# 2                          6.6648                                   122.5411
# 3                          6.0192                                  -176.8109
# 4                          5.6845                                   -36.0907
# 5                          5.6048                                  -458.8788
# 6                          4.9459                                  -156.3427
# 7                          5.8093                                    -0.8014
# 8                          7.1879                                   330.1435
# 9                          6.6321                                    84.2908
# 10                         5.9355                                  -369.9708
# 11                         5.7625                                   131.9161
# 12                         7.6550                                   458.5471
# 13                         7.0965                                   228.6915
# 14                         6.1025                                  -240.2350
# 15                         6.4271                                  -414.0873
# 16                         7.0531                                   319.0039
# 17                         6.9547                                   181.4041
# 18                         6.3186                                   -88.9975
# 19                         6.4750                                  -162.8197
# 20                         5.7772                                   285.9845
# 21                         6.0167                                   -13.4568
# 22                         5.8340                                  -292.3660
# 23                         6.7987                                    51.7871
# 24                         6.3786                                   146.4451
# 25                         6.0515                                    67.1620
# 26                         5.8490                                    13.5482
# 27                         5.6346                                  -416.3027
# 28                         5.4980                                  -169.2202
# 29                         5.1694                                  -315.0214
#
#     avg_vertical_distance_difference  points_difference  \
# 0                            -0.6651             29.608
# 1                            -0.6632             -5.329
# 2                             0.9481            -12.956
# 3                             0.6128              5.567
# 4                            -0.7548            -11.117
# 5                            -0.2785             -7.798
# 6                            -0.8339             -4.533
# 7                            -0.0995             14.244
# 8                             2.4262              6.924
# 9                            -1.0174             11.024
# 10                            1.1093             -8.616
# 11                           -1.0145              8.258
# 12                            0.6246             15.457
# 13                           -0.2135              4.393
# 14                           -0.2822             16.854
# 15                            0.1467            -10.909
# 16                           -1.7632             -8.662
# 17                            1.0083             -4.783
# 18                            3.8149              6.871
# 19                           -0.4811              5.817
# 20                           -0.3078             24.495
# 21                           -0.8892             13.289
# 22                            1.0644            -13.092
# 23                           -0.1358             -2.061
# 24                           -1.1769              4.512
# 25                            0.1801            -13.877
# 26                           -0.6708              1.017
# 27                            0.2410              7.119
# 28                           -0.0483              1.444
# 29                            0.9436             -9.802
#
#     pass_accuracy_difference  team_performance
# 0                     0.0114              Good
# 1                    -0.0060               Bad
# 2                    -0.0049               Bad
# 3                    -0.0035               Bad
# 4                    -0.0094               Bad
# 5                    -0.0034               Bad
# 6                     0.0043               Bad
# 7                    -0.0009               Bad
# 8                    -0.0078               Bad
# 9                     0.0029              Good
# 10                   -0.0159               Bad
# 11                    0.0034              Good
# 12                   -0.0112               Bad
# 13                    0.0009              Good
# 14                    0.0035              Good
# 15                   -0.0065               Bad
# 16                    0.0038               Bad
# 17                    0.0056               Bad
# 18                   -0.0109               Bad
# 19                    0.0008               Bad
# 20                    0.0066              Good
# 21                    0.0002              Good
# 22                   -0.0072               Bad
# 23                    0.0166               Bad
# 24                   -0.0018               Bad
# 25                    0.0101               Bad
# 26                   -0.0054               Bad
# 27                   -0.0054               Bad
# 28                    0.0091              Good
# 29                   -0.0037               Bad
#
# [30 rows x 34 columns]

# %%
# player metrics
player_metrics_xgoals = data_frames['MLSNP_players_xgoals'].copy()
player_metrics_xgoals['goal_difference'] = player_metrics_xgoals['goals'] - player_metrics_xgoals['xgoals']

player_metrics_xpass = data_frames['MLSNP_players_xpass'].copy()
player_metrics_xpass['pass_accuracy_difference'] = player_metrics_xpass['pass_completion_percentage'] - player_metrics_xpass['xpass_completion_percentage']

merged_player_metrics = pd.merge(player_metrics_xgoals, player_metrics_xpass, on='player_id', suffixes=('_xgoals', '_xpass'))

merged_player_metrics['player_performance'] = 'Good'
merged_player_metrics.loc[merged_player_metrics['goal_difference'] < 0, 'player_performance'] = 'Bad'
merged_player_metrics.loc[merged_player_metrics['pass_accuracy_difference'] < 0, 'player_performance'] = 'Bad'

print(merged_player_metrics)
# Out:
#       player_id                team_id_xgoals general_position_xgoals  \
# 0    0Oq624kdq6                    0Oq6Yad56D                      CB
# 1    0Oq624oPq6                    KXMe8Z2Q64                       W
# 2    0Oq62L42q6                    a35reDLML6                       W
# 3    0Oq62Oo2q6                    eV5Dw4EMKn                       W
# 4    0Oq62Y3zq6                    a35reDLML6                      GK
# ..          ...                           ...                     ...
# 995  KXMe8mgxQ6                    7VqG1oWMvW                      CM
# 996  KXMe8nlPQ6  ['KXMe8Z2Q64', 'eVq3Z0D5WO']                      ST
# 997  KXMe8NYXQ6                    jYQJXkP5GR                      FB
# 998  KXMe8VRrQ6                    Oa5wDy8q14                      CB
# 999  KXMegRk3q6                    kRQaW3L5KZ                      FB
#
#      minutes_played_xgoals  shots  shots_on_target  goals  xgoals  xplace  \
# 0                     1214      4                1      0  0.1802 -0.1250
# 1                      307      7                1      0  0.3831 -0.3384
# 2                      776     19                5      1  0.9500 -0.5246
# 3                       66      0                0      0  0.0000  0.0000
# 4                     1879      0                0      0  0.0000  0.0000
# ..                     ...    ...              ...    ...     ...     ...
# 995                   3289     21                8      2  1.1812  0.5274
# 996                   2431     83               36     12  6.1340  2.9281
# 997                     99      1                0      0  0.0271 -0.0271
# 998                   2146     14                1      0  1.5376 -1.1301
# 999                    266      1                0      0  0.0610 -0.0610
#
#      goals_minus_xgoals  ...  pass_completion_percentage  \
# 0               -0.1802  ...                      0.8582
# 1               -0.3831  ...                      0.8351
# 2                0.0500  ...                      0.7472
# 3                0.0000  ...                      0.8571
# 4                0.0000  ...                      0.8315
# ..                  ...  ...                         ...
# 995              0.8188  ...                      0.8585
# 996              5.8660  ...                      0.7586
# 997             -0.0271  ...                      0.7921
# 998             -1.5376  ...                      0.8312
# 999             -0.0610  ...                      0.8212
#
#      xpass_completion_percentage  passes_completed_over_expected  \
# 0                         0.8463                          8.1036
# 1                         0.8124                          4.2675
# 2                         0.7646                         -4.6226
# 3                         0.8174                          0.5562
# 4                         0.8432                         -6.5303
# ..                           ...                             ...
# 995                       0.8613                         -4.7626
# 996                       0.7381                         21.4607
# 997                       0.7700                          2.2264
# 998                       0.8347                         -4.6934
# 999                       0.7934                          4.1941
#
#      passes_completed_over_expected_p100  avg_distance_yds  \
# 0                                 1.1847           21.0481
# 1                                 2.2699           18.8125
# 2                                -1.7444           17.6840
# 3                                 3.9729           24.8803
# 4                                -1.1703           27.2415
# ..                                   ...               ...
# 995                              -0.2739           19.1457
# 996                               2.0478           19.7341
# 997                               2.2043           18.9647
# 998                              -0.3521           24.4666
# 999                               2.7775           21.7570
#
#      avg_vertical_distance_yds  share_team_touches  count_games  \
# 0                       7.5001              0.0723           16
# 1                       0.8436              0.1094            3
# 2                       3.5420              0.0326           18
# 3                      -1.0949              0.0512            1
# 4                      17.6340              0.0504           19
# ..                         ...                 ...          ...
# 995                     0.8041              0.0833           42
# 996                     4.3759              0.0794           30
# 997                     3.4983              0.0561            3
# 998                     5.8353              0.0757           30
# 999                     6.4085              0.1164            3
#
#     pass_accuracy_difference player_performance
# 0                     0.0119                Bad
# 1                     0.0227                Bad
# 2                    -0.0174                Bad
# 3                     0.0397               Good
# 4                    -0.0117                Bad
# ..                       ...                ...
# 995                  -0.0028                Bad
# 996                   0.0205               Good
# 997                   0.0221                Bad
# 998                  -0.0035                Bad
# 999                   0.0278                Bad
#
# [1000 rows x 32 columns]
